# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
from csv import writer

# %%
url = "https://economictimes.indiatimes.com/markets/stocks/news"

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.0.0 Safari/537.36'
}

# %%
r = requests.get(url, {'headers':headers})

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
soup.find_all()
# Out:
# [<html class="no-js" lang="en" xmlns:g="http://base.google.com/ns/1.0" xmlns:java="java" xmlns:listval="com.indiatimes.cms.utilities.CMSDateUtility" xmlns:nohtml="com.til.utils.CommonUtils" xmlns:valurl="com.times.utilities.CMSWebUtility" xmlns:xhtml="http://www.w3.org/1999/xhtml"><head><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><meta charset="utf-8"/><title>Stocks in News Today - Latest News on Stocks, Stock in News | The Economic Times</title><script>
#              (function() {
#
#                  // Boomerang Loader Snippet version 14
#
#                  if (window.BOOMR && (window.BOOMR.version || window.BOOMR.snippetExecuted)) {
#
#                      return;
#
#                  }
#
#                  window.BOOMR = window.BOOMR || {};
#
#                  window.BOOMR.snippetStart = new Date().getTime();
#
#                  window.BOOMR.snippetExecuted = true;
#
#                  window.BOOMR.snippetVersion = 14;
#
#                  window.BOOMR.url = "https://s.go-mpulse.net/boomerang/YH6JX-MK2F6-SLQKK-DW68V-VAT5D";
#
#                  // document.currentScript is supported in all browsers other than IE
#
#                  where = document.currentScript || document.getElementsByTagName("script")[0],
#
#                  // Parent element of the script we inject
#
#                  parentNode = where.parentNode,
#
#                  // Whether or not Preload method has worked
#
#                  promoted = false,
#
#                  // How long to wait for Preload to work before falling back to iframe method
#
#                  LOADER_TIMEOUT = 3000;
#
#                  // Tells the browser to execute the Preloaded script by adding it to the DOM
#
#                  function promote() {
#
#                      if (promoted) {
#                          return;
#                      }
#
#                      var script = document.createElement("script");
#
#                      script.id = "boomr-scr-as";
#
#                      script.src = window.BOOMR.url;
#
#                      // Not really needed since dynamic scripts are async by default and the script is already in cache at this point,
#
#                      // but some naive parsers will see a missing async attribute and think we're not async
#
#                      script.async = true;
#
#                      parentNode.appendChild(script);
#
#                      promoted = true;
#                  }
#
#                  // Non-blocking iframe loader (fallback for non-Preload scenarios) for all recent browsers.
#
#                  // For IE 6/7, falls back to dynamic script node.
#
#                  function iframeLoader(wasFallback) {
#
#                      promoted = true;
#
#                      var dom, doc = document, bootstrap, iframe, iframeStyle, win = window;
#
#                      window.BOOMR.snippetMethod = wasFallback ? "if" : "i";
#
#                      // Adds Boomerang within the iframe
#
#                      bootstrap = function(parent, scriptId) {
#
#                          var script = doc.createElement("script");
#
#                          script.id = scriptId || "boomr-if-as";
#
#                          script.src = window.BOOMR.url;
#
#                          BOOMR_lstart = new Date().getTime();
#
#                          parent = parent || doc.body;
#
#                          parent.appendChild(script);
#
#                      };
#
#                      // For IE 6/7, we'll just load the script in the current frame, as those browsers don't support 'about:blank'
#
#                      // for an iframe src (it triggers warnings on secure sites).  This means loading on IE 6/7 may cause SPoF.
#
#                      if (!window.addEventListener && window.attachEvent && navigator.userAgent.match(/MSIE [67]\./)) {
#
#                          window.BOOMR.snippetMethod = "s";
#
#                          bootstrap(parentNode, "boomr-async");
#
#                          return;
#                      }
#
#                      // The rest of this function is IE8+ and other browsers that don't support Preload hints but will work with CSP & iframes
#
#                      iframe = document.createElement("IFRAME");
#
#
#                      // An empty frame
#
#                      iframe.src = "about:blank";
#
#
#
#                      // We set title and role appropriately to play nicely with screen readers and other assistive technologies
#
#                      iframe.title = "";
#
#                      iframe.role = "presentation";
#
#
#
#                      // Ensure we're not loaded lazily
#
#                      iframe.loading = "eager";
#
#
#
#                      // Hide the iframe
#
#                      iframeStyle = (iframe.frameElement || iframe).style;
#
#                      iframeStyle.width = 0;
#
#                      iframeStyle.height = 0;
#
#                      iframeStyle.border = 0;
#
#                      iframeStyle.display = "none";
#
#
#                      // Append to the end of the current block
#
#                      parentNode.appendChild(iframe);
#
#
#                      // Try to get the iframe's document object
#
#                      try {
#
#                          win = iframe.contentWindow;
#
#                          doc = win.document.open();
#
#                      }
#
#                      catch (e) {
#
#                          // document.domain has been changed and we're on an old version of IE, so we got an access denied.
#
#                          // Note: the only browsers that have this problem also do not have CSP support.
#
#                          // Get document.domain of the parent window
#
#                          dom = document.domain;
#
#
#                          // Set the src of the iframe to a JavaScript URL that will immediately set its document.domain to match the parent.
#
#                          // This lets us access the iframe document long enough to inject our script.
#
#                          // Our script may need to do more domain massaging later.
#
#                          iframe.src = "javascript:var d=document.open();d.domain='" + dom + "';void 0;";
#
#                          win = iframe.contentWindow;
#
#                          doc = win.document.open();
#
#                      }
#
#
#                      if (dom) {
#
#                          // Unsafe version for IE8 compatibility. If document.domain has changed, we can't use win, but we can use doc.
#
#                          doc._boomrl = function() {
#
#                              this.domain = dom;
#
#                              bootstrap();
#
#                          };
#
#
#
#                          // Run our function at load.
#
#                          // Split the string so HTML code injectors don't get confused and add code here.
#
#                          doc.write("<bo" + "dy onload='document._boomrl();'>");
#
#                      }
#
#                      else {
#
#                          // document.domain hasn't changed, regular method should be OK
#
#                          win._boomrl = function() {
#
#                              bootstrap();
#
#                          };
#
#
#
#                          if (win.addEventListener) {
#
#                              win.addEventListener("load", win._boomrl, false);
#
#                          }
#
#                          else if (win.attachEvent) {
#
#                              win.attachEvent("onload", win._boomrl);
#
#                          }
#
#                      }
#
#                      // Finish the document
#
#                      doc.close();
#
#                  }
#
#                  // See if Preload is supported or not
#
#                  var link = document.createElement("link");
#
#                  if (link.relList &&
#
#                      typeof link.relList.supports === "function" &&
#
#                      link.relList.supports("preload") &&
#
#                      ("as" in link)) {
#
#                      window.BOOMR.snippetMethod = "p";
#
#
#
#                      // Set attributes to trigger a Preload
#
#                      link.href = window.BOOMR.url;
#
#                      link.rel  = "preload";
#
#                      link.as   = "script";
#
#
#
#                      // Add our script tag if successful, fallback to iframe if not
#
#                      link.addEventListener("load", promote);
#
#                      link.addEventListener("error", function() {
#
#                          iframeLoader(true);
#
#                      });
#
#
#
#                      // Have a fallback in case Preload does nothing or is slow
#
#                      setTimeout(function() {
#
#                          if (!promoted) {
#
#                              iframeLoader(true);
#
#                         }
#
#                      }, LOADER_TIMEOUT);
#
#
#
#                      // Note the timestamp we started trying to Preload
#
#                      BOOMR_lstart = new Date().getTime();
#
#
#
#                      // Append our link tag
#
#                      parentNode.appendChild(link);
#
#                  }
#
#                  else {
#
#                      // No Preload support, use iframe loader
#
#                      iframeLoader(false);
#
#                  }
#
#
#
#                  // Save when the onload event happened, in case this is a non-NavigationTiming browser
#
#                  function boomerangSaveLoadTime(e) {
#
#                      window.BOOMR_onload = (e && e.timeStamp) || new Date().getTime();
#
#                  }
#
#
#
#                  if (window.addEventListener) {
#
#                      window.addEventListener("load", boomerangSaveLoadTime, false);
#
#                  }
#
#                  else if (window.attachEvent) {
#
#                      window.attachEvent("onload", boomerangSaveLoadTime);
#
#                  }
#
#              })();
#
#          </script><!--/mpulsescript.cmspotime:2--><link href="/manifest.cms" rel="manifest"/><link href="https://www.google-analytics.com" rel="preconnect"/><link href="https://connect.facebook.net" rel="preconnect"/><link href="https://cm.g.doubleclick.net" rel="preconnect"/><link href="https://googleads.g.doubleclick.net" rel="preconnect"/><link href="https://googleads.g.doubleclick.net" rel="preconnect"/><link href="https://img.etimg.com" rel="preconnect"/><link href="https://js.etimg.com" rel="preconnect"/><link href="https://css.etimg.com" rel="preconnect"/><link href="https://economictimes.indiatimes.com" rel="preconnect"/><link href="https://sb.scorecardresearch.com" rel="preconnect"/><link href="https://ade.clmbtech.com" rel="preconnect"/><link href="https://www.googletagservices.com" rel="preconnect"/><link href="https://ads.pubmatic.com" rel="preconnect"/><link href="https://securepubads.g.doubleclick.net" rel="preconnect"/><link href="https://static.clmbtech.com" rel="preconnect"/><link href="https://json.bselivefeeds.indiatimes.com" rel="preconnect"/><link href="https://mcxlivefeeds.indiatimes.com" rel="preconnect"/><link href="//www.google-analytics.com" rel="dns-prefetch"/><link href="//connect.facebook.net" rel="dns-prefetch"/><link href="//cm.g.doubleclick.net" rel="dns-prefetch"/><link href="//googleads.g.doubleclick.net" rel="dns-prefetch"/><link href="//googleads.g.doubleclick.net" rel="dns-prefetch"/><link href="https://img.etimg.com" rel="dns-prefetch"/><link href="//js.etimg.com" rel="dns-prefetch"/><link href="//css.etimg.com" rel="dns-prefetch"/><link href="//economictimes.indiatimes.com" rel="dns-prefetch"/><link href="//sb.scorecardresearch.com" rel="dns-prefetch"/><link href="https://ade.clmbtech.com" rel="dns-prefetch"/><link href="https://marketcharts.indiatimes.com" rel="dns-prefetch"/><link href="https://jssocdn.indiatimes.com" rel="dns-prefetch"/><link href="https://jsso.indiatimes.com" rel="dns-prefetch"/><link href="https://static.growthrx.in" rel="dns-prefetch"/><link as="font" crossorigin="anonymous" href="/fonts/faustina-v6-latin-500.woff2" rel="preload"/><link as="font" crossorigin="anonymous" href="/fonts/montserrat-v14-latin-regular.woff2" rel="preload"/><link as="font" crossorigin="anonymous" href="/fonts/montserrat-v14-latin-500.woff2" rel="preload"/><link as="font" crossorigin="anonymous" href="/fonts/montserrat-v14-latin-600.woff2" rel="preload"/><link as="font" crossorigin="anonymous" href="/fonts/montserrat-v14-latin-700.woff2" rel="preload"/><script>window.pageLoadStarted = (new Date()).getTime();</script><meta content="21540067693" property="fb:pages"/><link href="https://economictimes.indiatimes.com/icons/etfavicon.ico" rel="shortcut icon" type="image/x-icon"/><link href="https://economictimes.indiatimes.com/thumb/width-120,height-120,msid-75267040/et.jpg" rel="apple-touch-icon"/><link href="https://c.amazon-adsystem.com" rel="dns-prefetch"/><link crossorigin="anonymous" href="https://c.amazon-adsystem.com" rel="preconnect"/><meta content="index,follow" name="robots"/><meta content="width=device-width, initial-scale=1.0" name="viewport"/><meta content="117787264903013" property="fb:app_id"/><meta content="556964827" property="fb:admins"/><meta content="Stocks in News Today - Latest News on Stocks, Stock in News | The Economic Times" property="og:title"/><meta content="Stocks in News - Find the latest Stocks in News on The Economic Times. Get Stocks Analysis, News on Stocks and more." property="og:description"/><meta content="The Economic Times" property="og:site_name"/><meta content="website" property="og:type"/><meta content="https://economictimes.indiatimes.com/markets/stocks/news/articlelist/2146843.cms" property="og:url"/><meta content="https://img.etimg.com/photo/65498029.cms" property="og:image"/><link href="https://img.etimg.com/photo/65498029.cms" rel="image_src"/><meta content="https://economictimes.indiatimes.com" name="website"/><meta content="website" name="object_ty ...
#  	        function errorLogs(data, fallback) { if(data && window.location.search.indexOf('utm_source') == -1) { try { var o = window.location.origin, isLive = (o.indexOf('dev') == -1 && o.indexOf('pwa') == -1 ? 1 : 0), url = data.href || data.src || '', type = (data.localName || data.tagName) + (data.attributes.fallbackfile ? ' fallbackfile': ''), ua = window.navigator && window.navigator.userAgent; var logdata = "logdata=" + JSON.stringify({mode: (isLive ? 'modeLive' : 'modeDev'), channel:'Error_desktop', type:type, data:encodeURIComponent(url), userAgent: ua, url: window.location.href}); var xhr = new XMLHttpRequest(); xhr.withCredentials = true; xhr.open("POST", "https://etx.indiatimes.com/log?et=errorLogs"); xhr.setRequestHeader("Content-Type", "application/x-www-form-urlencoded"); xhr.send(logdata); var fpArr = url.split('.com'), fp = fpArr[1], ft = fp.indexOf('js_') != -1 && 'js' || fp.indexOf('css_') != -1 && 'css'; !fallback && loadAssets(ft, fp); } catch (e) {} } }
#
#  	        function loadAssets(t, f) {
#  	            //f = f + (f.indexOf('?')!=-1?'&':'?')+'ref=fallbackFile'
#                  if (t=="js"){
#                      var fileref=document.createElement('script')
#                      fileref.setAttribute("type","text/javascript")
#                      fileref.setAttribute("src", f)
#                  } else if (t=="css"){
#                      var fileref=document.createElement("link")
#                      fileref.setAttribute("rel", "stylesheet")
#                      fileref.setAttribute("type", "text/css")
#                      fileref.setAttribute("href", f)
#                  }
#                  if (typeof fileref!="undefined"){
#                      fileref.setAttribute("fallbackfile", "1")
#                      fileref.setAttribute("onerror", "errorLogs(this, 1)")
#                      document.getElementsByTagName("head")[0].appendChild(fileref)
#                  }
#              }
#
#  	    </script><link href="https://css.etimg.com/d/et_fonts/v-9,minify-1.cms" onerror="errorLogs(this)" rel="stylesheet" type="text/css"/><link href="https://css.etimg.com/d/css_common_new/v-235,minify-1.cms" onerror="errorLogs(this)" rel="stylesheet" type="text/css"/><link href="https://css.etimg.com/d/css_listnew/v-77,minify-1.cms" onerror="errorLogs(this)" rel="stylesheet" type="text/css"/><link href="https://economictimes.indiatimes.com/rssfeeds/2146843.cms" rel="alternate" type="application/rss+xml"/><script type="text/javascript">var subsec1_value = '1977021501',
#  				        listContentType = '';
#  				        var buyname = 'markets/stocks/news';
#  				    var intv,intv2;var fo;
#  					objPage = {template:'articlelist'};
#  					var skinningExist = false, subsec2 = '2146842', sloadflag = 1;
#  					var msid = '2146843',pgno = 2, loadflag = 1;
#  					if(msid == '2147477890'){
#  					    window.location.href = 'https://economictimes.indiatimes.com';
#  					}
#  					var msidforprimewidget ='60187373';
#  					</script><script type="text/javascript">var newslistred = "",
#  				newseo = "stocks-in-news-today-latest-news-on-stocks-stock-in-news-the-economic-times";
#  				newseo = newseo ? "/"+ newseo : "";
#  				if(newslistred == "newslist"){
#  				    window.location = newseo+"/newslist/"+msid+".cms";
#  				}
#
#  				</script><link href="https://m.economictimes.com/markets/stocks/news" media="only screen and (max-width: 640px)" rel="alternate"/><link href="https://m.economictimes.com/markets/stocks/news" media="handheld" rel="alternate"/><link href="https://economictimes.indiatimes.com/markets/stocks/news" rel="canonical"/><link href="https://m.economictimes.com/markets/stocks/news/amp_articlelist/2146843.cms" rel="amphtml"/><script type="text/javascript">
#  				    var referrer = document.referrer;
#      				    var pgMsid = '2146843';
#
#      				    if(window.location.href.indexOf('articlelist') != -1 && (pgMsid == '6175976' || pgMsid == '63079086')){
#      				        ga('send','event', 'Temp', 'articlelist Referrer', referrer);
#      				    }
#
#  				 </script><script type="text/javascript">if(typeof geolocation != 'undefined' && geolocation != 1 && geolocation != 5){
#  				var crtg_nid = '4306';
#                      var crtg_cookiename = 'crtg_rta';
#                      var crtg_varname = 'crtg_content';
#                      function crtg_getCookie(c_name){ var i,x,y,ARRCookies=document.cookie.split(";");for(i=0;i<ARRCookies.length;i++){x=ARRCookies[i].substr(0,ARRCookies[i].indexOf("="));y=ARRCookies[i].substr(ARRCookies[i].indexOf("=")+1);x=x.replace(/^\s+|\s+$/g,"");if(x==c_name){return unescape(y);} }return'';}
#                      var crtg_content = crtg_getCookie(crtg_cookiename);
#                      var crtg_rnd=Math.floor(Math.random()*99999999999);
#                      (function(){
#                      var crtg_url=location.protocol+'//rtax.criteo.com/delivery/rta/rta.js?netId='+escape(crtg_nid);
#                      crtg_url +='&cookieName='+escape(crtg_cookiename);
#                      crtg_url +='&rnd='+crtg_rnd;
#                      crtg_url +='&varName=' + escape(crtg_varname);
#                      var crtg_script=document.createElement('script');crtg_script.type='text/javascript';crtg_script.src=crtg_url;crtg_script.async=true;
#                      if(document.getElementsByTagName("head").length>0)document.getElementsByTagName("head")[0].appendChild(crtg_script);
#                      else if(document.getElementsByTagName("body").length>0)document.getElementsByTagName("body")[0].appendChild(crtg_script);
#                      })();
#  				}
#  				// eliminate js plugins
#                  skip = {facebook_js: 1};
#
#  				</script><link href="https://economictimes.indiatimes.com/markets/stocks/news/articlelist/msid-2146843,page-2.cms" rel="next"/><script type="text/javascript">
#
#  					/* ========== MF redirection to actual MF URL ============ */
#  					if(document.querySelector){
#  					var canonicalUrl = document.querySelector('link[rel=canonical]').getAttribute('href'),
#  					links = document.getElementsByTagName("link");
#  					canonicalUrl = canonicalUrl.substr(canonicalUrl.indexOf(':') + 1);
#  				    canonicalUrl = canonicalUrl.replace(/m.economictimes.com/g,"economictimes.indiatimes.com");
#  					(function () {
#  					    var ru = '', cu = canonicalUrl, ls = location.search, lp = location.pathname, et_ = 'economictimes.indiatimes.com';
#  					    if(location.host == et_ && ls.toLowerCase().indexOf('utm') == -1) {
#          					if (cu.indexOf("//" + et_) >= 0 && cu.split(".com")[1] != lp) {
#          						ru = cu + ls;
#          					}
#      					}
#      					if(ru != '') {
#      					    if(typeof localStorage != 'undefined') {
#      						    localStorage.setItem('pageRedirectToCan', window.location.href + ' - ' + document.referrer);
#      						}
#      						document.location.href = ru
#      					}
#  					})();
#  					}
#  					/* ========== Ends MF redirection to actual MF URL ============ */
#
#  				</script><script>(function() {var lh = location.host; if(lh.indexOf('economictimes.com') == -1 && lh.indexOf('india'+'times'+'.com') == -1 && lh.indexOf('archive'+'.org') == -1 && lh.indexOf('webcache' + '.googleusercontent'+ '.com') == -1) { window.location.href = 'https' + '://' + 'economictimes' + '.indiatimes.'+ 'com' + '?frmref=' + location.host }})()</script><script>
#
#  	        function getCookie(n) {var ne = n + "=", ca = document.cookie.split(';');for (var i=0;i< ca.length;i++){ var c = ca[i]; while (c.charAt(0) == ' ') c = c.substring(1, c.length); if (c.indexOf(ne) == 0) return c.substring(ne.length, c.length); } return null; }
#
#
#  	    var objVc = {version_on:'2022.07.12 10:25',vcLScacheTime:'10',js_etsubscription:'2',js_onboarding_popup_sh:'11',js_comments:'111',js_googleslock:'782',js_googlelogin:'62',js_common_buydirect:'751',js_bookmark:'20',js_follow:'12',js_highcharts:'3',js_highcharts3d:'1',js_sr_search:'1',js_ask_the_expert_crypto:'16',js_articleshow_main:'176',css_articleshow_new:'92',js_login:'79',js_datepicker:'2',js_push:'59',js_slikeplayernew:'15',css_buydirect:'14',css_commoncalc:'27',js_tradenow:'26',interstitial_web:'1',int_countrychk_web:'1',int_allowedcountry_web:'1',int_fequencycap_web:'3',js_common_wap:'266',js_common_markets_wap:'5',js_sr_search_wap:'8',js_ask_the_expert_crypto_wap:'16',js_commonall:'142',wap_interstitial_start:'Jun 03, 2021 23:59:00',wap_interstitial_end:'July 22, 2022 23:59:00',int_countrychk_wap:'0',int_allowedcountry_wap:'1,2',cpd_wap:'1',lib_login:'/jsso_crosswalk_legacy_min.cms',live_tv:'{"onoff_flag":"0","platform":"desktop","sections":["1977021501","1715249553","13352306","5575607","837555174","359241701","13357270","107115","897228639","7771250","1466318837"],"pages":"all","auto_open":"1","default_tv":"0","timePeriod":{"showTimeFlag":false,"fromTime":"","toTime":""},"preRollAd":1,"content_default_tv":"content_default_tv_0"}',live_tv_skin:'0',global_cube:'0',global_cube_wap:'0',global_cube_faces:'2',global_cube_fullad:'0',global_cube_landingon:'sensex',global_cube_wap_url:'https://m.economictimes.com/iframe_cube.cms',currency_ad_wap:'1',site_sync:'0',ticker_ad:'0',aff_package:'bnsov',aff_package_wap:'bnsov',ticker_ad_home:'0',adx:'1',amazon_bidding:'0',amazon_tam:'1',amazon_tam_web:'0',js_newsltrpopup:'126',nlExpiry:'864000',nlReloadExpiry:'30',js_primetargeting_popup:'6',js_inappmsg:'8',fan_ads:'0',plan_on_paywall:'0',skip_trial:'100',planEntryPointCache:'3',trackAdCode:'0',ajaxError:'1',cTId:'WWW-R7W-Z45Z',oauth:'oauth2',planPage:'/plans.cms',planPageTest:'https://economictimes.indiatimes.com/plans.cms',subscriptions:'subscriptions',krypton:'kryptonp',apw:'apw',nlSubscribe:'etsub3',exp_login2plan:'0',js_ratingwidget:'9',js_swg:'4',swg:'1',login_paywall:'Starting @ <strike>Rs150</strike> Rs120/month',singularPlanExp:'0',intro_offer_banner:'0',ctaTxtExp:'50',mf_defaultTab:'1',intro_offer:'0',article_recommendations:'50',primeTargeting:'1',skipnlpopup:'1',skipCryptoPopup:'1',skipMouseflow:'1',js_article_recommendations:'21',skiparticle_recommendations_rhs:'1',skiparticle_recommendations_in:'1',skipwhatsapp_banner:'1',liveTvLsName:'bandTvCheckPlayed3',liveTvLsValue:'3600',survicate_loyaluser_count:'15',js_etbenefits:'19',js_giftstory:'5',disable_MFOP_wap:'1',dummy:''};
#          (function(){
#
#              try {var lsd = localStorage.getItem('objVc'), lsdj = lsd && JSON.parse(lsd) || '', vo = objVc.version_on, lv = new Date(vo), sv = lsdj && lsdj.version_on && new Date(lsdj.version_on) || 0, diff = (sv-lv) / 60000;
#                  if(sv && diff >= 0) {objVc = lsdj;}
#                  else {
#                      var now = Date(), vodo = new Date(vo);
#                      objVc.lsTime = vodo > now ? now.toString() : vo; localStorage.setItem('objVc', JSON.stringify(objVc))
#                  }
#                  if(window.location.search.indexOf('skip_popup=1') != -1) { objVc.skipPopup = 1; }
#              } catch(e) {}
#
#          })()
#          </script><iframe height="0" id="__tiluuid_frame" style="display:none" width="0"></iframe><script>
#  		try {
#  		var __tiluuid = localStorage.getItem('__tiluuid');
#          var __tiluuid_expiry_ms = parseInt(localStorage.getItem('__tiluuid_expiry_ms')) || 1607000000410;
#          if (__tiluuid_expiry_ms <= (new Date()).getTime() || localStorage.getItem('__tiluuid') == null) {
#              function receiveMessage(evt) {
#                  if (evt.origin === 'https://tilanalytics.timesinternet.in') {
#                      if (evt.data && evt.data.__tiluuid) {
#                          __tiluuid = evt.data.__tiluuid;
#                          localStorage.setItem('__tiluuid', __tiluuid);
#                          var isValid = /^[0-9A-F]{8}-[0-9A-F]{4}-4[0-9A-F]{3}-[89AB][0-9A-F]{3}-[0-9A-F]{12}-[0-9]+$/i.test(__tiluuid);
#                          if (isValid) {
#                              localStorage.setItem('__tiluuid_expiry_ms', evt.data.__tiluuid_expiry_ms);
#  							try {
#  							 if (ga){ ga('set', {'dimension57': __tiluuid});}
#  						 	}catch(e) {}
#
#                          }
#                          if (evt.data.reset === true && evt.data.__tiluuid_reset_script_path) {
#                              var reset_tiluuid_element = document.createElement("script");
#                              reset_tiluuid_element.setAttribute("src", (evt.data.__tiluuid_reset_script_path));
#                              document.head.appendChild(reset_tiluuid_element);
#                          }
#                      }
#                  }
#              }
#
#              window.addEventListener('message', receiveMessage, false);
#              document.getElementById("__tiluuid_frame").src = 'https://tilanalytics.timesinternet.in/production/frame-2.1.min.html';
#          }
#
#          var _col_uuid;
#          function setColuuid(){for(var o="_col_uuid=",n=decodeURIComponent(document.cookie).split(";"),t=0;t<n.length;t++){for(var u=n[t];" "==u.charAt(0);)u=u.substring(1);0==u.indexOf(o)&&(_col_uuid=u.substring(o.length,u.length))}};
#          setColuuid();
#
#          }catch(e) {}
#  		    </script><!--/tiluuidscript.cmspotime:2--><script id="geo_script" src="https://economictimes.indiatimes.com/geoapiet?cb=et" type="text/javascript"></script><script>
#  		    geolocation = window.geoinfo && window.geoinfo.geolocation || '';
#  			if(window.localStorage && localStorage.getItem('temp_geolocation')) {var geolocation = localStorage.getItem('temp_geolocation');}
#  		    function allowGDPR() {
#  		        var flag = false, ginfo = window.geoinfo || {};
#  		        if(window.geolocation && geolocation != 5 && (geolocation != 2 || ginfo.region_code != 'CA')) {flag = true;}
#  		        return flag;
#  		    }
#  		    allowGdpr = (function () {
#                  var flag = 0, ginfo = window.geoinfo || {};
#                  // if not EU(5), and (not US(2) if US(2) then not california(CA))
#                  if(window.geolocation && geolocation != 5 && (geolocation != 2 || ginfo.region_code != 'CA')) {
#                      flag = 1;
#                  }
#                  return flag;
#  		    })()
#  		    </script><!--/geolocationscript.cmspotime:1--><script>
#  		    var urlParams =window.location.search ? window.location.search : "";
#
#
#  		            var ext_param_check=-1==urlParams.indexOf("utm_medium=display_ext"),aff_param_check=-1==urlParams.indexOf("utm_medium=display_aff");aff_param_check||sessionStorage.setItem("aff_campaign","1"),ext_param_check&&aff_param_check&&function(){objVc=window.objVc||{};var e=objVc.int_countrychk_web?parseInt(objVc.int_countrychk_web):1,t=objVc.int_allowedcountry_web;t=t&&t.split?t.split(","):["1"];var i=objVc.int_fequencycap_web?parseInt(objVc.int_fequencycap_web):3,o={setCookieToSpecificTime:function(e,t,i,o){try{var a="";if(e&&t&&i&&(a=e+"="+escape(t)+"; expires="+new Date((new Date).toDateString()+" "+i).toUTCString()+"; domain=.indiatimes.com; path=/;"),e&&t&&o){var n=new Date;n.setSeconds(n.getSeconds()+o),a=e+"="+(escape(t)+(null==o?"":"; expires="+n.toUTCString())+"; domain=.indiatimes.com; path=/;")}document.cookie=a}catch(e){}},init:function(){var e=1==objVc.interstitial_web?1:0;if(-1!=window.location.search.indexOf("ints=0")&&(e=0),e){var t=getCookie("TicketId"),i=o.getOauthJStorage(t),a=i&&i.permissions||[],n=-1==a.indexOf("subscribed")||-1==a.indexOf("etadfree_subscribed")||0==a.length||0,r=getCookie("ssoid")||getCookie("MSCSAuthID");(!r||r&&!n)&&o.loadInterstitial()}},loadInterstitial:function(){try{var a=document.referrer;if(!(a.indexOf("/ad-free/success")>-1||a.indexOf("/ad-free/subscribed"))>-1||localStorage.getItem("devTool")){var n=window.location,r=navigator&&navigator.userAgent&&navigator.userAgent.toLowerCase()||"",c=-1!=r.indexOf("bot"),s=-1!=r.indexOf("lighthouse"),f=-1!=r.indexOf("ptst_x/"),d=getCookie("int_fcapcount")||0,g=getCookie("et_interstitial_active"),l=window.geoinfo&&geoinfo.geolocation||"1",u=t.indexOf(l);if(!(/(\?|&)?(from=mdr)/.test(n.href)||c||s||f||g||!(d<i)||0!=e&&-1==u)){o.setCookieToSpecificTime("et_interstitial_active","true","",40);var _=parseInt(d)+1;_<=i&&o.setCookieToSpecificTime("int_fcapcount",_,"23:59:59"),window.sessionStorage&&window.sessionStorage.setItem("intsRef",window.location.href);return window.location.replace("/defaultinterstitial.cms"),!1}}}catch(e){window.errorLogs&&errorLogs({href:JSON.stringify(objVc),localName:"interstitial_error",attributes:""},1)}},getOauthJStorage:function(e){try{return jStorageData=window.localStorage&&localStorage.jStorage?JSON.parse(localStorage.jStorage):{},jStorageData["prime_"+e]}catch(e){}}};o.init()}();
#
#  		        </script><!--/interstitialscript.cms?v=8potime:2--><script onerror="errorLogs(this)" src="https://js.etimg.com/d/js_monetize/v-116,minify-1.cms" type="text/javascript"></script><script async="async" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js" type="text/javascript"></script><script type="text/javascript">
#  	        var optParam = '';
#  	        try {
#  	        var urlParams = window.URLSearchParams && new URLSearchParams(window.location.search),
#  	            optParam = urlParams.get && urlParams.get('opt');
#  	        } catch (e) {}
#
#  	        var objSec = {template: 'articlelist', msid:'2146843', hostid:'153', secNames: ['markets','stocks','news'],secIds:['2147477890','1977021501','2146842','2146843']};
#          var tmplName = tpName = 'articlelist',lang = '',nav_sec1,newHookId,subsec1_value,subsec1_common = '1977021501',newHookId2,subsec2_value,subsec2_common = '2146842',subsec3_common = '2146843';
#          var objDim = {d52:'nature_of_content',d96:'continuous_paywall_hits',d95:'monthly_article_count',d10:'user_login_status_hit',d54:'content_shelf_life',d98:'daily_paid_article_count',d110:'paywall_signaling',d53:'content_target_audience',d97:'monthly_paid_article_count',d12:'tags_meta_keyword',d56:'degree_of_conten',d11:'content_theme_the_primary_tag',d55:'content_tone',d99:'response_source',d14:'special_coverage',d58:'et_product_item',d13:'article_publish_time',d16:'video_embed',d15:'audio_embed',d59:'show_paywall_final',d61:'paywall_probability',d60:'paywall_score',d63:'paid_articles_read',d101:'ml_score',d62:'eligibility_paywall_rule',d102:'ml_threshold_value',d65:'bureau_articles_read',d20:'platform',d64:'free_articles_read',d100:'ml_status',d23:'author_id',d67:'loyalty',d66:'article_length',d25:'page_template',d24:'syft_initiate_page',d68:'paywall_hits',d27:'site_sub_section',d26:'site_section',d29:'section_id',d28:'prime_deal_code',d109:'user_region',d70:'us_election_2020',d72:'paywall_experiment',d103:'adaptive_status',d71:'plan_group_id',d32:'prime_article_read_before_syft',d75:'watchlist_active_status',d34:'content_age',d33:'prime_article_read_before_success',d36:'sign_in_initiation_position',d35:'subscription_method_hit',d37:'user_subscription_status',d1:'et_product',d2:'blocker_type',d3:'user_login_status_session',d4:'agency',d5:'author_name',d6:'cms_content_publishing_type',d7:'content_personalisation_level',d8:'article_publish_date',d9:'sub_section_name',d40:'freeread',d45:'prime_hp_ui_template',d47:'prime_hp_ui_content_b_color',d46:'prime_hp_ui_content_size',d49:'syft_initiate_position',d48:'content_msid',d92:'last_click_source',d50:'signin_initiate_page',d94:'daily_article_count',d93:'internal_source'};var serverTime = '07.12.2022 10:28:45';var WRInitTime=(new Date()).getTime();
#              (function () {if (self !== top) {var e = function (s) {return document.getElementsByTagName(s)}; e("head")[0].innerHTML = '<style>*{display:none;}</style>'; setTimeout(function () {e("body")[0].innerHTML = ''; var hEle = e("html")[0]; hEle.innerHTML = '<a href="' + self.location + '" target="_blank">economictimes.indiatimes.com</a>'; hEle.className = ''; top.location = self.location; }, 0);}})();
#
#          _log = window.console && console.log ? console.log : function () {};
#  		// Creating Elements for IE : HTML 5 and cross domain checks
#  		(function () {
#      		try {
#      		    var elem = ["article", "aside", "figure", "footer", "figcaption", "header", "nav", "section", "time"];
#      		    for(var i=0; i<=elem.length-1; i++) {document.createElement(elem[i])} var hd = 'indiatimes.com', dd = document.domain,intv,intv2,fo; if (dd != hd && dd.indexOf(hd) != -1) {document.domain = hd}
#      		}catch(e){}
#  		})();
#  		var intv,intv2;var fo;
#  		if(subsec1_value == '1715249553' && subsec2_value == '1052732854'){
#  			subsec1_value = newHookId = '1052732854'; // politicsnation
#  		}else if(subsec1_value == '1715249553' && subsec2_value == '1373380680'){
#  			subsec1_value = newHookId = '1373380680'; // Economy
#  		}
#
#  		if(optParam != "1") {
#
#
#  	    customDimension = window.customDimension || {};
#  	    function setDim(dim, val, init) { try { if(dim) { var key = 'dimension' + dim, objDim = {}; objDim[key] = val; customDimension[key] = val; init && ga('set', objDim); } }catch(e){} }
#
#
#                  var _gaq = _gaq || [];
#                  var customDimension = customDimension || {};
#                  var analytics_js_path = 'https://www.google-analytics.com/analytics.js';
#                  (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#                  (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#                  m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#                  })(window,document,'script',analytics_js_path,'ga');
#                  var gaProperty = 'UA-198011-5';
#                  var disableStr = 'ga-disable';
#                  if (document.cookie.indexOf(disableStr + '=true') > -1) { window[disableStr + '-' + gaProperty] = true; }
#
#                  ga('set', 'anonymizeIp', true);
#                  ga('create', gaProperty, 'auto', {'allowLinker': true});
#                  ga('require', 'linker');
#                  ga('linker:autoLink', ['economictimes.com']);
#                  ga('require', 'displayfeatures');
#                  try {
#                      var et_ua = window.navigator && navigator.userAgent || '';
#                      if(et_ua.toLowerCase().indexOf('bot') == -1) {
#                          window.optimizely = window.optimizely || [];
#                          window.optimizely.push("activateUniversalAnalytics");
#                          ga('require', 'GTM-WV452H7');
#                      }
#                  } catch (e) {}
#
#                  (function () {
#                      setDim(25,"articlelist");
#                      setDim(26,"Markets");
#                      setDim(27,"Markets/Stocks/News");
#                      setDim(29,"1977021501");
#                      setDim(48,"2146843");
#                      setDim(30,window._col_uuid);setDim(57,window.__tiluuid);
#
#
#                      if(window.geolocation) {setDim(109, window.geolocation == 1 ? 'IND' : 'INTER');}
#                      var a = window.localStorage && localStorage.getItem('et_syftCounter') || '';
#                      a = a && JSON.parse(a) || {};
#                      if(a.beforeSyft) {setDim(32,a.beforeSyft);}
#                      if(a.afterSyft) {setDim(33,a.afterSyft);}
#                  })()
#
#
#
#  	    var trafficSource = '';
#  	    function getjStorageVal(keyName) { var jString = localStorage.getItem("jStorage"), value = ''; try { if(jString) { var objJstorage = JSON.parse(jString); value = objJstorage[keyName] ? objJstorage[keyName] : ''; } } catch (e) {} return value; }
#  		(function () {
#  		    function addZero(num) {return (num >= 0 && num < 10) ? '0' + num : num;}
#  		    try {
#      		    lastClick = getjStorageVal('etu_last_click');
#                  if(!lastClick) {
#                      lastClick = document.referrer.indexOf('indiatimes.com') == -1 ? 'direct_landing_articleshow' : 'other';
#                  }
#                  var dref = document.referrer, wlh = window.location.href.toLowerCase(), wlp = window.location.pathname;
#                  if(/google|bing|yahoo/ig.test(dref)) {trafficSource = 'organic';}
#                  else if(/facebook|linkedin|instagram|twitter/ig.test(dref) || wlh.indexOf('utm_medium=social') != -1) { trafficSource = 'social';}
#                  else if(wlh.indexOf('utm_medium=email') != -1) {trafficSource = 'newsletter'; }
#                  else if(wlh.indexOf('utm_source=etnotifications') != -1) {trafficSource = 'notifications'; }
#                  else if(getjStorageVal('etu_source')) { trafficSource = getjStorageVal('etu_source');}
#
#                  if(!trafficSource) {
#                      if(wlp == '/' || wlp == '/default.cms') {trafficSource = 'direct'}
#                      else if(wlp.indexOf('articleshow')) {trafficSource = 'organic'}
#                      else {trafficSource = 'other'}
#                  }
#
#                  var dtObject = new Date(), dt = (dtObject.getFullYear() + '' + addZero(dtObject.getMonth() + 1) + '' + addZero(dtObject.getDate())), key = 'et_article_' + dt;
#                  var articleReadCountToday = (getjStorageVal(key) || []).length;
#                  var articleReadCountMonth = 0;
#                  var paidArticleReadCountMonth = 0;
#                  var jString = localStorage.getItem("jStorage");
#                  try {
#                      if(jString) {
#                          var objJstorage = JSON.parse(jString);
#                          Object.keys(objJstorage).filter(function(key) {return key.indexOf('et_article_') != -1}).forEach(function (key) { articleReadCountMonth += getjStorageVal(key).length});
#                          Object.keys(objJstorage).filter(function(key) {return key.indexOf('et_primearticle_') != -1}).forEach(function (key) { paidArticleReadCountMonth += getjStorageVal(key) || 0});
#                      }
#  	            } catch (e) {}
#
#                  var paidArticleReadCountTodayKey = 'et_primearticle_' + dt;
#                  var paidArticleReadCountToday = getjStorageVal(paidArticleReadCountTodayKey) || 0;
#                  var continuousPaywallList = getjStorageVal('et_continuousPaywalled') || [];
#
#
#                  setDim(92, lastClick);
#                  setDim(93, trafficSource);
#                  setDim(94, articleReadCountToday);
#                  setDim(95, articleReadCountMonth);
#                  setDim(96, continuousPaywallList.length);
#                  setDim(97, paidArticleReadCountMonth);
#                  setDim(98, paidArticleReadCountToday);
#
#                  var subsStatus = '-', d3 = 'NONLOGGEDIN';
#                  var jData = JSON.parse(localStorage.getItem('jStorage'));
#                  var b = document.getElementsByTagName('html')[0];
#                  if(ssoid = getCookie('ssoid')) {
#                      try {
#                          d3 = 'LOGGEDIN';
#                          var grx_userData = jData['prime_'+getCookie('TicketId')];
#                          grx_userData = grx_userData || {};
#                          var grx_up = grx_userData.permissions || [];
#                          if(grx_up.indexOf("expired_subscription") > -1) {
#                              subsStatus = 'Expired User';
#          		        } else if (grx_up.indexOf("subscribed") > -1 && grx_up.indexOf("cancelled_subscription") > -1 && grx_up.indexOf("can_buy_subscription") > -1) {
#          		            subsStatus = 'Paid User - In Trial';
#          		            b.classList.add("cancelled_user");
#          		        } else if(grx_up.indexOf("subscribed") > -1) {
#          		            subsStatus = 'Paid User';
#                              b.classList.add("prime_user");
#          		        } else if(grx_up.indexOf("etadfree_subscribed") > -1) {
#          		            subsStatus = 'Ad Free User';
#          		        } else if (grx_up.length == 0) {
#          		            subsStatus = 'Permission Missing';
#          		        } else {
#          		            subsStatus = 'Free User';
#          		        }
#
#          		        if(grx_up.indexOf("subscribed") > -1) {
#          		            var lsKey = 'et_nhp_' + ssoid, bucket = window.localStorage && localStorage.getItem(lsKey) || '', bucketArr = bucket.split('-');
#                              if(window.location.search.indexOf('dev=1') != -1 || (bucketArr[0] == 1)) {
#          				        b.classList.add("prime_header");
#          				    }
#          		        }
#      		        } catch (e) {}
#                  } else {
#                      subsStatus = 'Free User';
#                  }
#
#                  if(subsStatus == '-' || subsStatus == '' || subsStatus == 'Expired User' || subsStatus == 'Free User') {
#                      b.classList.add("free_user");
#                  }
#                  setDim(3, d3); setDim(10, d3); setDim(37, subsStatus);
#
#  		    } catch (e) {}
#  		})();
#
#
#  	    setDim(1,'other');setDim(24,'articlelist');
#
#                  ga('send', 'pageview', customDimension);
#
#
#      		    var newHookId ='1977021501';
#
#          			var subsec1_value ='1977021501', subsec1_2value = '2146842';
#
#      			        if(subsec1_value == '1715249553' && subsec1_2value == '1052732854'){
#      			            subsec1_value = '1052732854'; // politicsnation
#      			        }else if(subsec1_value == '1715249553' && subsec1_2value == '1373380680'){
#      			            subsec1_value = '1373380680'; // Economy
#      			        }
#
#
#
#          (function (g, r, o, w, t, h, rx) {
#              g[t] = g[t] || function () {(g[t].q = g[t].q || []).push(arguments)
#              }, g[t].l = 1 * new Date();
#              g[t] = g[t] || {}, h = r.createElement(o), rx = r.getElementsByTagName(o)[0];
#              h.async = 1;h.src = w;rx.parentNode.insertBefore(h, rx)
#          })(window, document, 'script', 'https://static.growthrx.in/js/v2/web-sdk.js', 'grx');
#          grx('init', 'gf999c70d');
#          var grxDimension = {url: window.location.href, title : document.title, referral_url : document.referrer, platform: 'desktop'};
#          var pfuuid = getCookie('pfuuid');
#          if(pfuuid) { grxDimension['et_uuid'] = pfuuid}
#
#
#              (function () {
#                  grx('userId', getCookie('ssoid') || '-');
#                  try {
#                      if(window.localStorage && localStorage.getItem) {
#                          var jString = localStorage.getItem("jStorage");
#                          if(jString) {
#                              var objJstorage = JSON.parse(jString), objProf = objJstorage['et_subscription_profile'], userInfo = objJstorage['userInfo'] || {}, peuuid = getCookie('peuuid'), pfuuid = getCookie('pfuuid');
#                              for (var attrname in objProf) { grxDimension[attrname] = objProf[attrname]; };
#                              var dt = new Date(), tDate = dt.getDate()+'-'+(dt.getMonth()+1)+'-'+dt.getFullYear(),loggedIn = (getCookie('ssoid') ? 'Y' : 'N');
#                              grxDimension['first_date_on_et'] = objJstorage['et_first_date'] || tDate;
#                              grxDimension['last_visited_date'] = tDate;
#                              grxDimension['logged_in'] = userInfo['email'] ? 'Y' : 'N';
#                              grxDimension['email'] = userInfo['email'] || '-';
#                              grxDimension['first_name'] = userInfo['fname'] || '-';
#                              grxDimension['last_name'] = userInfo['lname'] || '-';
#                              grxDimension['current_subscriber_status'] = customDimension.dimension37 || '-';
#                              if(peuuid) {grxDimension['web_peuuid'] = peuuid;}
#                              if(pfuuid) {grxDimension['web_pfuuid'] = pfuuid;}
#                          }
#                      }
#                      if(window.customDimension && window.objDim) {
#                          for(key in customDimension) {
#                              var dimId = 'd' + key.substr(9, key.length);
# ...
#  <img alt="Extrapolating crypto market crash to equities" class="lazy" data-original="/thumb/msid-92337333,quality-100,width-92,imglength-102310,resizemode-1/extrapolating-crypto-market-crash-to-equities.jpg" src="https://img.etimg.com/photo/42031747.cms" width="92"/>,
#  <div class="speaker_details"><h5><a href="/etreporter/author-jigar-mistry-479256938.cms" target="_blank">Jigar Mistry</a></h5><p>Co-Founder &amp; Director, Buoyant Capital</p></div>,
#  <h5><a href="/etreporter/author-jigar-mistry-479256938.cms" target="_blank">Jigar Mistry</a></h5>,
#  <a href="/etreporter/author-jigar-mistry-479256938.cms" target="_blank">Jigar Mistry</a>,
#  <p>Co-Founder &amp; Director, Buoyant Capital</p>,
#  <li class="clearfix"><div class="speaker_img"><img alt="Meme NFTs - The new way to make money?" class="lazy" data-original="/thumb/msid-92142556,quality-100,width-92,imglength-38130,resizemode-1/meme-nfts-the-new-way-to-make-money.jpg" src="https://img.etimg.com/photo/42031747.cms" width="92"/></div><div class="speaker_details"><h5><a href="/etreporter/author-taaran-chanana-479257968.cms" target="_blank">Taaran Chanana</a></h5><p>MD and Co-Founder, MemeChat</p></div></li>,
#  <div class="speaker_img"><img alt="Meme NFTs - The new way to make money?" class="lazy" data-original="/thumb/msid-92142556,quality-100,width-92,imglength-38130,resizemode-1/meme-nfts-the-new-way-to-make-money.jpg" src="https://img.etimg.com/photo/42031747.cms" width="92"/></
jpg" src="https://img.etimg.com/photo/42031747.cms" width="92"/></div>,
#  <img alt="Should you start accepting salary in Bitcoin?" class="lazy" data-original="/thumb/msid-90455216,quality-100,width-92,imglength-56992,resizemode-1/should-you-start-accepting-salary-in-bitcoin.jpg" src="https://img.etimg.com/photo/42031747.cms" width="92"/>,
#  <div class="speaker_details"><h5><a href="/etreporter/author-bhagaban-behera-479257209.cms" target="_blank">Bhagaban Behera</a></h5><p>CEO and Co-Founder, Defy</p></div>,
#  <h5><a href="/etreporter/author-bhagaban-behera-479257209.cms" target="_blank">Bhagaban Behera</a></h5>,
#  <a href="/etreporter/author-bhagaban-behera-479257209.cms" target="_blank">Bhagaban Behera</a>,
#  <p>CEO and Co-Founder, Defy</p>,
#  <li class="clearfix"><div class="speaker_img"><img alt="Blockchain gives sports clubs a lucrative way to increase their fandom" class="lazy" data-original="/thumb/msid-89776238,quality-100,width-92,imglength-74038,resizemode-1/blockchain-gives-sports-clubs-a-lucrative-way-to-increase-their-fandom.jpg" src="https://img.etimg.com/photo/42031747.cms" width="92"/></div><div class="speaker_details"><h5><a href="/etreporter/author-siddharth-jaiswal-479256620.cms" target="_blank">Siddharth Jaiswal</a></h5><p>Founder &amp; CEO, SportZchain</p></div></li>,
#  <div class="speaker_img"><img alt="Blockchain gives sports clubs a lucrative way to increase their fandom" class="lazy" data-original="/thumb/msid-89776238,quality-100,width-92,imglength-74038,resizemode-1/blockchain-gives-sports-clubs-a-lucrative-way-to-increase-their-fandom.jpg" src="https://img.etimg.com/photo/42031747.cms" width="92"/></div>,
#  <img alt="Blockchain gives sports clubs a lucrative way to increase their fandom" class="lazy" data-original="/thumb/msid-89776238,quality-100,width-92,imglength-74038,resizemode-1/blockchain-gives-sports-clubs-a-lucrative-way-to-increase-their-fandom.jpg" src="https://img.etimg.com/photo/42031747.cms" width="92"/>,
#  <div class="speaker_details"><h5><a href="/etreporter/author-siddharth-jaiswal-479256620.cms" target="_blank">Siddharth Jaiswal</a></h5><p>Founder &amp; CEO, SportZchain</p></div>,
#  <h5><a href="/etreporter/author-siddharth-jaiswal-479256620.cms" target="_blank">Siddharth Jaiswal</a></h5>,
#  <a href="/etreporter/author-siddharth-jaiswal-479256620.cms" target="_blank">Siddharth Jaiswal</a>,
#  <p>Founder &amp; CEO, SportZchain</p>,
#  <div class="step_1"><textarea data-label="Your Answer" data-limit="200" maxlength="1000" name="questiontext" placeholder="Enter your Query*" rel="200" value=""></textarea><div class="condiTxt"><p class="error">Provide valid query here</p><small>Max. characters: 1000</small></div><div class="btnSec"><button class="jsSubmitQuestion" type="button">next</button></div></div>,
#  <textarea data-label="Your Answer" data-limit="200" maxlength="1000" name="questiontext" placeholder="Enter your Query*" rel="200" value=""></textarea>,
#  <div class="condiTxt"><p class="error">Provide valid query here</p><small>Max. characters: 1000</small></div>,
#  <p class="error">Provide valid query here</p>,
#  <small>Max. characters: 1000</small>,
#  <div class="btnSec"><button class="jsSubmitQuestion" type="button">next</button></div>,
#  <button class="jsSubmitQuestion" type="button">next</button>,
#  <div class="step_2 hidden"><input id="name" name="name" placeholder="Name*" type="text"/><p class="error">Provide valid Name</p><input id="emailid" name="email" placeholder="Email ID*" type="email"/><p class="error">Provide valid Email ID</p><input id="phoneno" name="phoneno" placeholder="Mobile*" type="text"/><p class="error">Provide valid Mobile Number</p><div class="checkBox"><label class="checkBoxLabel"><input id="" name="agreTnc" type="checkbox"/><span class="checkBoxCustme"></span></label><span>I agree with the Program <a href="https://economictimes.indiatimes.com/photo/85363868.cms" target="_blank">T&amp;C</a>, <a href="https://economictimes.indiatimes.com/privacypolicy.cms" target="_blank">Privacy Policy</a>, <a href="https://economictimes.indiatimes.com/terms-conditions" target="_blank">Terms of use</a> and for sharing my details with the partner of this program</span></div><div class="btnSec"><button class="jsSubmitQuestionFinel" type="submit">Submit</button></div></div>,
#  <input id="name" name="name" placeholder="Name*" type="text"/>,
#  <p class="error">Provide valid Name</p>,
#  <input id="emailid" name="email" placeholder="Email ID*" type="email"/>,
#  <p class="error">Provide valid Email ID</p>,
#  <input id="phoneno" name="phoneno" placeholder="Mobile*" type="text"/>,
#  <p class="error">Provide valid Mobile Number</p>,
#  <div class="checkBox"><label class="checkBoxLabel"><input id="" name="agreTnc" type="checkbox"/><span class="checkBoxCustme"></span></label><span>I agree with the Program <a href="https://economictimes.indiatimes.com/photo/85363868.cms" target="_blank">T&amp;C</a>, <a href="https://economictimes.indiatimes.com/privacypolicy.cms" target="_blank">Privacy Policy</a>, <a href="https://economictimes.indiatimes.com/terms-conditions" target="_blank">Terms of use</a> and for sharing my details with the partner of this program</span></div>,
#  <label class="checkBoxLabel"><input id="" name="agreTnc" type="checkbox"/><span class="checkBoxCustme"></span></label>,
#  <input id="" name="agreTnc" type="checkbox"/>,
#  <span class="checkBoxCustme"></span>,
#  <span>I agree with the Program <a href="https://economictimes.indiatimes.com/photo/85363868.cms" target="_blank">T&amp;C</a>, <a href="https://economictimes.indiatimes.com/privacypolicy.cms" target="_blank">Privacy Policy</a>, <a href="https://economictimes.indiatimes.com/terms-conditions" target="_blank">Terms of use</a> and for sharing my details with the partner of this program</span>,
#  <a href="https://economictimes.indiatimes.com/photo/85363868.cms" target="_blank">T&amp;C</a>,
#  <a href="https://economictimes.indiatimes.com/privacypolicy.cms" target="_blank">Privacy Policy</a>,
#  <a href="https://economictimes.indiatimes.com/terms-conditions" target="_blank">Terms of use</a>,
#  <div class="btnSec"><button class="jsSubmitQuestionFinel" type="submit">Submit</button></div>,
#  <button class="jsSubmitQuestionFinel" type="submit">Submit</button>,
#  <div class="step_3 hidden"><div class="thnkSec"><p class="thanksMessage">Your query has been submitted. </p><p class="jsAskNow">Got more Queries ?</p><a class="askNow" data-ga-onclick="Crypto Corner#Ask The Expert -  All Question# href" href="/crypto_asktheexpert.cms" target="_blank">All Questions </a></div></div>,
#  <div class="thnkSec"><p class="thanksMessage">Your query has been submitted. </p><p class="jsAskNow">Got more Queries ?</p><a class="askNow" data-ga-onclick="Crypto Corner#Ask The Expert -  All Question# href" href="/crypto_asktheexpert.cms" target="_blank">All Questions </a></div>,
#  <p class="thanksMessage">Your query has been submitted. </p>,
#  ...]

# %%
soup.find_all('div')
# Out:
# [<div class="innov" data-adsslot="ET_Markets/ET_Markets_Stocks/ET_ROS_SKIN_MKT_SKT_RHS_125" data-loc="All" data-oop="0" data-size="[[160, 600], [120, 600], [125, 600]]" id="div-gpt-ad-innov-2146843" subsec1="1977021501" subsec2="2146842"></div>,
#  <div class="skinning_left" data-adsslot="ET_Markets/ET_Markets_Stocks/ET_ROS_SKIN_MKT_SKT_LHS_125" data-fallback="1" data-loc="All" data-size="[[160, 600], [120, 600], [125, 600]]" id="skinningleft_backup" subsec1="1977021501" subsec2="2146842"></div>,
#  <div data-adsslot="/7176/Economictimes/ET_ROS_Sticky_160" data-fallback="1" data-loc="All" data-oop="1" data-size="[[160, 600], [120, 600], [125, 600]]" id="ROS_Sticky_160_Fallback" style="position: fixed; top: 0px; left: 0; margin-left: calc((100% - 1003px) / 2 - -1004px);"></div>,
#  <div class="primeDW" id="topAd" l1="1977021501" l2="2146842" l3="2146843" lan=""><section id="topAd"><div data-adsslot="ET_Markets/ET_Markets_Stocks/ET_ROS_ATF_MKT_STK_728" data-loc="All" data-oop="0" data-size="[[1003, 90],[970,90],[728, 90]]" id="div-gpt-ad-1481103461078-25"></div></section></div>,
#  <div data-adsslot="ET_Markets/ET_Markets_Stocks/ET_ROS_ATF_MKT_STK_728" data-loc="All" data-oop="0" data-size="[[1003, 90],[970,90],[728, 90]]" id="div-gpt-ad-1481103461078-25"></div>,
#  <div class="band"><div class="contentwrapper bandCont clearfix"><div class="flipWrapper" style="float: left;"><div class="mkt_indices_band clearfix"><div class="band-items" id="S1_box"><div class="band-item clearfix"><div class="band-content"><div class="head"><a href="https://economictimes.indiatimes.com/indices/nifty_50_companies" target="_blank">Benchmarks </a></div><div class="values"><a class="wname" href="https://economictimes.indiatimes.com/indices/nifty_50_companies" target="_blank">Nifty</a><span class="num">16,151.15</span><span class="per cSprite_b red">-64.85</span></div></div></div></div><div class="band-items" id="S2_box"><div class="band-item clearfix"><div class="band-content"><div class="head"><a href="https://economictimes.indiatimes.com/marketstats/duration-1d,marketcap-largecap,pageno-1,pid-0,sort-intraday,sortby-percentchange,sortorder-desc.cms" target="_blank">NSE Gainer-Large Cap </a></div><div class="values"><a class="wname" href="/adani-green-energy-ltd/stocks/companyid-64847.cms" target="_blank">Adani Green</a><span class="num">2,325.95</span><span class="per cSprite_b green">118.6</span></div></div></div></div><div class="S5_box_wrapper"><div class="band-items" id="S5_box"><a data-ga-onclick="Buy Direct - Edelweiss#WEB - Click - Edelweiss Small Cap Fund Direct - Growth - Invest Now - MarketBand#MarketBand - url" href="https://www.edelweissmf.com/types-of-mutual-funds/equity-fund/edelweiss-small-cap-fund?utm_source=EconomicTimes&amp;utm_medium=Widget&amp;utm_campaign=ProductWidget&amp;utm_id=ETProductWidget&amp;utm_term=Edelweiss+Small+Cap%2C+Small+Cap%2C+Equity+Fund" rel="nofollow sponsored" target="_blank"><div class="band-item clearfix"><div class="band-content-left"><div class="head"><span class="lbl">FEATURED FUNDS</span><div class="ratings flr"><span class="rating">★★★★</span><span class="ratingGrey">★</span></div></div><div class="title" title="Edelweiss Small Cap Fund Direct - Growth">Edelweiss Small Cap Fund Direct - Growth</div></div><div class="band-content-right flt"><div class="head lbl">3Y Return</div><div class="values flt"><span class="per cSprite_b green">30.46 %
#                  </span></div><div class="cta flt">Invest Now</div></div></div></a><a data-ga-onclick="Buy Direct - DSP#WEB - Click - DSP Midcap Direct Plan-Growth - Invest Now - MarketBand#MarketBand - url" href="https://invest.dspim.com/mutual-fund-products/equity-schemes/mid-cap-small-and-mid-cap-fund/dspsm-direct-growth?utm_source=ET&amp;utm_medium=MF_Widget&amp;utm_campaign=ET-Midcap-Widget-Jul21&amp;utm_content=ET-Midcap-Widget" rel="nofollow sponsored" target="_blank"><div class="band-item clearfix"><div class="band-content-left"><div class="head"><span class="lbl">FEATURED FUNDS</span><div class="ratings flr"><span class="rating">★★★</span><span class="ratingGrey">★★</span></div></div><div class="title" title="DSP Midcap Direct Plan-Growth">DSP Midcap Direct Plan-Growth</div></div><div class="band-content-right flt"><div class="head lbl">5Y Return</div><div class="values flt"><span class="per cSprite_b green">10.65 %
#                  </span></div><div class="cta flt">Invest Now</div></div></div></a><a data-ga-onclick="Buy Direct - DSP#WEB - Click - DSP Tax Saver Direct Plan-Growth - Invest Now - MarketBand#MarketBand - url" href="https://invest.dspim.com/mutual-fund-products/equity-schemes/ELSS-tax-saver-fund/dspts-direct-growth?utm_source=ET&amp;utm_medium=MF_Widget&amp;utm_campaign=ET-ELSS-Widget-Jul21&amp;utm_content=ET-ELSS-Widget" rel="nofollow sponsored" target="_blank"><div class="band-item clearfix"><div class="band-content-left"><div class="head"><span class="lbl">FEATURED FUNDS</span><div class="ratings flr"><span class="rating">★★★★</span><span class="ratingGrey">★</span></div></div><div class="title" title="DSP Tax Saver Direct Plan-Growth">DSP Tax Saver Direct Plan-Growth</div></div><div class="band-content-right flt"><div class="head lbl">5Y Return</div><div class="values flt"><span class="per cSprite_b green">13.15 %
#                  </span></div><div class="cta flt">Invest Now</div></div></div></a><a data-ga-onclick="Buy Direct - Edelweiss#WEB - Click - Edelweiss Flexi Cap Fund Direct-Growth - Invest Now - MarketBand#MarketBand - url" href="https://www.edelweissmf.com/types-of-mutual-funds/equity-fund/edelweiss-flexicap-fund?utm_source=EconomicTimes&amp;utm_medium=Widget&amp;utm_campaign=ProductWidget&amp;utm_id=ETProductWidget&amp;utm_term=Edelweiss+Flexi+Cap%2C+Multi+Cap+Fund" rel="nofollow sponsored" target="_blank"><div class="band-item clearfix"><div class="band-content-left"><div class="head"><span class="lbl">FEATURED FUNDS</span><div class="ratings flr"><span class="rating">★★★</span><span class="ratingGrey">★★</span></div></div><div class="title" title="Edelweiss Flexi Cap Fund Direct-Growth">Edelweiss Flexi Cap Fund Direct-Growth</div></div><div class="band-content-right flt"><div class="head lbl">5Y Return</div><div class="values flt"><span class="per cSprite_b green">12.97 %
#                  </span></div><div class="cta flt">Invest Now</div></div></div></a></div></div></div></div><div class="band-items grey"><div class="stats_btn"><a class="mktWatch" href="/marketstats/pid-0,pageno-1,sortby-percentchange,sortorder-desc,sort-intraday.cms?marketcap=largecap%252Cmidcap" target="_blank">Market Watch</a><div class="stats_list"></div></div></div></div></div>,
#  <div class="contentwrapper bandCont clearfix"><div class="flipWrapper" style="float: left;"><div class="mkt_indices_band clearfix"><div class="band-items" id="S1_box"><div class="band-item clearfix"><div class="band-content"><div class="head"><a href="https://economictimes.indiatimes.com/indices/nifty_50_companies" target="_blank">Benchmarks </a></div><div class="values"><a class="wname" href="https://economictimes.indiatimes.com/indices/nifty_50_companies" target="_blank">Nifty</a><span class="num">16,151.15</span><span class="per cSprite_b red">-64.85</span></div></div></div></div><div class="band-items" id="S2_box"><div class="band-item clearfix"><div class="band-content"><div class="head"><a href="https://economictimes.indiatimes.com/marketstats/duration-1d,marketcap-largecap,pageno-1,pid-0,sort-intraday,sortby-percentchange,sortorder-desc.cms" target="_blank">NSE Gainer-Large Cap </a></div><div class="values"><a class="wname" href="/adani-green-energy-ltd/stocks/companyid-64847.cms" target="_blank">Adani Green</a><span class="num">2,325.95</span><span class="per cSprite_b green">118.6</span></div></div></div></div><div class="S5_box_wrapper"><div class="band-items" id="S5_box"><a data-ga-onclick="Buy Direct - Edelweiss#WEB - Click - Edelweiss Small Cap Fund Direct - Growth - Invest Now - MarketBand#MarketBand - url" href="https://www.edelweissmf.com/types-of-mutual-funds/equity-fund/edelweiss-small-cap-fund?utm_source=EconomicTimes&amp;utm_medium=Widget&amp;utm_campaign=ProductWidget&amp;utm_id=ETProductWidget&amp;utm_term=Edelweiss+Small+Cap%2C+Small+Cap%2C+Equity+Fund" rel="nofollow sponsored" target="_blank"><div class="band-item clearfix"><div class="band-content-left"><div class="head"><span class="lbl">FEATURED FUNDS</span><div class="ratings flr"><span class="rating">★★★★</span><span class="ratingGrey">★</span></div></div><div class="title" title="Edelweiss Small Cap Fund Direct - Growth">Edelweiss Small Cap Fund Direct - Growth</div></div><div class="band-content-right flt"><div class="head lbl">3Y Return</div><div class="values flt"><span class="per cSprite_b green">30.46 %
#                  </span></div><div class="cta flt">Invest Now</div></div></div></a><a data-ga-onclick="Buy Direct - DSP#WEB - Click - DSP Midcap Direct Plan-Growth - Invest Now - MarketBand#MarketBand - url" href="https://invest.dspim.com/mutual-fund-products/equity-schemes/mid-cap-small-and-mid-cap-fund/dspsm-direct-growth?utm_source=ET&amp;utm_medium=MF_Widget&amp;utm_campaign=ET-Midcap-Widget-Jul21&amp;utm_content=ET-Midcap-Widget" rel="nofollow sponsored" target="_blank"><div class="band-item clearfix"><div class="band-content-left"><div class="head"><span class="lbl">FEATURED FUNDS</span><div class="ratings flr"><span class="rating">★★★</span><span class="ratingGrey">★★</span></div></div><div class="title" title="DSP Midcap Direct Plan-Growth">DSP Midcap Direct Plan-Growth</div></div><div class="band-content-right flt"><div class="head lbl">5Y Return</div><div class="values flt"><span class="per cSprite_b green">10.65 %
#                  </span></div><div class="cta flt">Invest Now</div></div></div></a><a data-ga-onclick="Buy Direct - DSP#WEB - Click - DSP Tax Saver Direct Plan-Growth - Invest Now - MarketBand#MarketBand - url" href="https://invest.dspim.com/mutual-fund-products/equity-schemes/ELSS-tax-saver-fund/dspts-direct-growth?utm_source=ET&amp;utm_medium=MF_Widget&amp;utm_campaign=ET-ELSS-Widget-Jul21&amp;utm_content=ET-ELSS-Widget" rel="nofollow sponsored" target="_blank"><div class="band-item clearfix"><div class="band-content-left"><div class="head"><span class="lbl">FEATURED FUNDS</span><div class="ratings flr"><span class="rating">★★★★</span><span class="ratingGrey">★</span></div></div><div class="title" title="DSP Tax Saver Direct Plan-Growth">DSP Tax Saver Direct Plan-Growth</div></div><div class="band-content-right flt"><div class="head lbl">5Y Return</div><div class="values flt"><span class="per cSprite_b green">13.15 %
#                  </span></div><div class="cta flt">Invest Now</div></div></div></a><a data-ga-onclick="Buy Direct - Edelweiss#WEB - Click - Edelweiss Flexi Cap Fund Direct-Growth - Invest Now - MarketBand#MarketBand - url" href="https://www.edelweissmf.com/types-of-mutual-funds/equity-fund/edelweiss-flexicap-fund?utm_source=EconomicTimes&amp;utm_medium=Widget&amp;utm_campaign=ProductWidget&amp;utm_id=ETProductWidget&amp;utm_term=Edelweiss+Flexi+Cap%2C+Multi+Cap+Fund" rel="nofollow sponsored" target="_blank"><div class="band-item clearfix"><div class="band-content-left"><div class="head"><span class="lbl">FEATURED FUNDS</span><div class="ratings flr"><span class="rating">★★★</span><span class="ratingGrey">★★</span></div></div><div class="title" title="Edelweiss Flexi Cap Fund Direct-Growth">Edelweiss Flexi Cap Fund Direct-Growth</div></div><div class="band-content-right flt"><div class="head lbl">5Y Return</div><div class="values flt"><span class="per cSprite_b green">12.97 %
#                  </span></div><div class="cta flt">Invest Now</div></div></div></a></div></div></div></div><div class="band-items grey"><div class="stats_btn"><a class="mktWatch" href="/marketstats/pid-0,pageno-1,sortby-percentchange,sortorder-desc,sort-intraday.cms?marketcap=largecap%252Cmidcap" target="_blank">Market Watch</a><div class="stats_list"></div></div></div></div>,
#  <div class="flipWrapper" style="float: left;"><div class="mkt_indices_band clearfix"><div class="band-items" id="S1_box"><div class="band-item clearfix"><div class="band-content"><div class="head"><a href="https://economictimes.indiatimes.com/indices/nifty_50_companies" target="_blank">Benchmarks </a></div><div class="values"><a class="wname" href="https://economictimes.indiatimes.com/indices/nifty_50_companies" target="_blank">Nifty</a><span class="num">16,151.15</span><span class="per cSprite_b red">-64.85</span></div></div></div></div><div class="band-items" id="S2_box"><div class="band-item clearfix"><div class="band-content"><div class="head"><a href="https://economictimes.indiatimes.com/marketstats/duration-1d,marketcap-largecap,pageno-1,pid-0,sort-intraday,sortby-percentchange,sortorder-desc.cms" target="_blank">NSE Gainer-Large Cap </a></div><div class="values"><a class="wname" href="/adani-green-energy-ltd/stocks/companyid-64847.cms" target="_blank">Adani Green</a><span class="num">2,325.95</span><span class="per cSprite_b green">118.6</span></div></div></div></div><div class="S5_box_wrapper"><div class="band-items" id="S5_box"><a data-ga-onclick="Buy Direct - Edelweiss#WEB - Click - Edelweiss Small Cap Fund Direct - Growth - Invest Now - MarketBand#MarketBand - url" href="https://www.edelweissmf.com/types-of-mutual-funds/equity-fund/edelweiss-small-cap-fund?utm_source=EconomicTimes&amp;utm_medium=Widget&amp;utm_campaign=ProductWidget&amp;utm_id=ETProductWidget&amp;utm_term=Edelweiss+Small+Cap%2C+Small+Cap%2C+Equity+Fund" rel="nofollow sponsored" target="_blank"><div class="band-item clearfix"><div class="band-content-left"><div class="head"><span class="lbl">FEATURED FUNDS</span><div class="ratings flr"><span class="rating">★★★★</span><span class="ratingGrey">★</span></div></div><div class="title" title="Edelweiss Small Cap Fund Direct - Growth">Edelweiss Small Cap Fund Direct - Growth</div></div><div class="band-content-right flt"><div class="head lbl">3Y Return</div><div class="values flt"><span class="per cSprite_b green">30.46 %
#                  </span></div><div class="cta flt">Invest Now</div></div></div></a><a data-ga-onclick="Buy Direct - DSP#WEB - Click - DSP Midcap Direct Plan-Growth - Invest Now - MarketBand#MarketBand - url" href="https://invest.dspim.com/mutual-fund-products/equity-schemes/mid-cap-small-and-mid-cap-fund/dspsm-direct-growth?utm_source=ET&amp;utm_medium=MF_Widget&amp;utm_campaign=ET-Midcap-Widget-Jul21&amp;utm_content=ET-Midcap-Widget" rel="nofollow sponsored" target="_blank"><div class="band-item clearfix"><div class="band-content-left"><div class="head"><span class="lbl">FEATURED FUNDS</span><div class="ratings flr"><span class="rating">★★★</span><span class="ratingGrey">★★</span></div></div><div class="title" title="DSP Midcap Direct Plan-Growth">DSP Midcap Direct Plan-Growth</div></div><div class="band-content-right flt"><div class="head lbl">5Y Return</div><div class="values flt"><span class="per cSprite_b green">10.65 %
#                  </span></div><div class="cta flt">Invest Now</div></div></div></a><a data-ga-onclick="Buy Direct - DSP#WEB - Click - DSP Tax Saver Direct Plan-Growth - Invest Now - MarketBand#MarketBand - url" href="https://invest.dspim.com/mutual-fund-products/equity-schemes/ELSS-tax-saver-fund/dspts-direct-growth?utm_source=ET&amp;utm_medium=MF_Widget&amp;utm_campaign=ET-ELSS-Widget-Jul21&amp;utm_content=ET-ELSS-Widget" rel="nofollow sponsored" target="_blank"><div class="band-item clearfix"><div class="band-content-left"><div class="head"><span class="lbl">FEATURED FUNDS</span><div class="ratings flr"><span class="rating">★★★★</span><span class="ratingGrey">★</span></div></div><div class="title" title="DSP Tax Saver Direct Plan-Growth">DSP Tax Saver Direct Plan-Growth</div></div><div class="band-content-right flt"><div class="head lbl">5Y Return</div><div class="values flt"><span class="per cSprite_b green">13.15 %
#                  </span></div><div class="cta flt">Invest Now</div></div></div></a><a data-ga-onclick="Buy Direct - Edelweiss#WEB - Click - Edelweiss Flexi Cap Fund Direct-Growth - Invest Now - MarketBand#MarketBand - url" href="https://www.edelweissmf.com/types-of-mutual-funds/equity-fund/edelweiss-flexicap-fund?utm_source=EconomicTimes&amp;utm_medium=Widget&amp;utm_campaign=ProductWidget&amp;utm_id=ETProductWidget&amp;utm_term=Edelweiss+Flexi+Cap%2C+Multi+Cap+Fund" rel="nofollow sponsored" target="_blank"><div class="band-item clearfix"><div class="band-content-left"><div class="head"><span class="lbl">FEATURED FUNDS</span><div class="ratings flr"><span class="rating">★★★</span><span class="ratingGrey">★★</span></div></div><div class="title" title="Edelweiss Flexi Cap Fund Direct-Growth">Edelweiss Flexi Cap Fund Direct-Growth</div></div><div class="band-content-right flt"><div class="head lbl">5Y Return</div><div class="values flt"><span class="per cSprite_b green">12.97 %
#                  </span></div><div class="cta flt">Invest Now</div></div></div></a></div></div></div></div>,
#  <div class="mkt_indices_band clearfix"><div class="band-items" id="S1_box"><div class="band-item clearfix"><div class="band-content"><div class="head"><a href="https://economictimes.indiatimes.com/indices/nifty_50_companies" target="_blank">Benchmarks </a></div><div class="values"><a class="wname" href="https://economictimes.indiatimes.com/indices/nifty_50_companies" target="_blank">Nifty</a><span class="num">16,151.15</span><span class="per cSprite_b red">-64.85</span></div></div></div></div><div class="band-items" id="S2_box"><div class="band-item clearfix"><div class="band-content"><div class="head"><a href="https://economictimes.indiatimes.com/marketstats/duration-1d,marketcap-largecap,pageno-1,pid-0,sort-intraday,sortby-percentchange,sortorder-desc.cms" target="_blank">NSE Gainer-Large Cap </a></div><div class="values"><a class="wname" href="/adani-green-energy-ltd/stocks/companyid-64847.cms" target="_blank">Adani Green</a><span class="num">2,325.95</span><span class="per cSprite_b green">118.6</span></div></div></div></div><div class="S5_box_wrapper"><div class="band-items" id="S5_box"><a data-ga-onclick="Buy Direct - Edelweiss#WEB - Click - Edelweiss Small Cap Fund Direct - Growth - Invest Now - MarketBand#MarketBand - url" href="https://www.edelweissmf.com/types-of-mutual-funds/equity-fund/edelweiss-small-cap-fund?utm_source=EconomicTimes&amp;utm_medium=Widget&amp;utm_campaign=ProductWidget&amp;utm_id=ETProductWidget&amp;utm_term=Edelweiss+Small+Cap%2C+Small+Cap%2C+Equity+Fund" rel="nofollow sponsored" target="_blank"><div class="band-item clearfix"><div class="band-content-left"><div class="head"><span class="lbl">FEATURED FUNDS</span><div class="ratings flr"><span class="rating">★★★★</span><span class="ratingGrey">★</span></div></div><div class="title" title="Edelweiss Small Cap Fund Direct - Growth">Edelweiss Small Cap Fund Direct - Growth</div></div><div class="band-content-right flt"><div class="head lbl">3Y Return</div><div class="values flt"><span class="per cSprite_b green">30.46 %
#                  </span></div><div class="cta flt">Invest Now</div></div></div></a><a data-ga-onclick="Buy Direct - DSP#WEB - Click - DSP Midcap Direct Plan-Growth - Invest Now - MarketBand#MarketBand - url" href="https://invest.dspim.com/mutual-fund-products/equity-schemes/mid-cap-small-and-mid-cap-fund/dspsm-direct-growth?utm_source=ET&amp;utm_medium=MF_Widget&amp;utm_campaign=ET-Midcap-Widget-Jul21&amp;utm_content=ET-Midcap-Widget" rel="nofollow sponsored" target="_blank"><div class="band-item clearfix"><div class="band-content-left"><div class="head"><span class="lbl">FEATURED FUNDS</span><div class="ratings flr"><span class="rating">★★★</span><span class="ratingGrey">★★</span></div></div><div class="title" title="DSP Midcap Direct Plan-Growth">DSP Midcap Direct Plan-Growth</div></div><div class="band-content-right flt"><div class="head lbl">5Y Return</div><div class="values flt"><span class="per cSprite_b green">10.65 %
#                  </span></div><div class="cta flt">Invest Now</div></div></div></a><a data-ga-onclick="Buy Direct - DSP#WEB - Click - DSP Tax Saver Direct Plan-Growth - Invest Now - MarketBand#MarketBand - url" href="https://invest.dspim.com/mutual-fund-products/equity-schemes/ELSS-tax-saver-fund/dspts-direct-growth?utm_source=ET&amp;utm_medium=MF_Widget&amp;utm_campaign=ET-ELSS-Widget-Jul21&amp;utm_content=ET-ELSS-Widget" rel="nofollow sponsored" target="_blank"><div class="band-item clearfix"><div class="band-content-left"><div class="head"><span class="lbl">FEATURED FUNDS</span><div class="ratings flr"><span class="rating">★★★★</span><span class="ratingGrey">★</span></div></div><div class="title" title="DSP Tax Saver Direct Plan-Growth">DSP Tax Saver Direct Plan-Growth</div></div><div class="band-content-right flt"><div class="head lbl">5Y Return</div><div class="values flt"><span class="per cSprite_b green">13.15 %
#                  </span></div><div class="cta flt">Invest Now</div></div></div></a><a data-ga-onclick="Buy Direct - Edelweiss#WEB - Click - Edelweiss Flexi Cap Fund Direct-Growth - Invest Now - MarketBand#MarketBand - url" href="https://www.edelweissmf.com/types-of-mutual-funds/equity-fund/edelweiss-flexicap-fund?utm_source=EconomicTimes&amp;utm_medium=Widget&amp;utm_campaign=ProductWidget&amp;utm_id=ETProductWidget&amp;utm_term=Edelweiss+Flexi+Cap%2C+Multi+Cap+Fund" rel="nofollow sponsored" target="_blank"><div class="band-item clearfix"><div class="band-content-left"><div class="head"><span class="lbl">FEATURED FUNDS</span><div class="ratings flr"><span class="rating">★★★</span><span class="ratingGrey">★★</span></div></div><div class="title" title="Edelweiss Flexi Cap Fund Direct-Growth">Edelweiss Flexi Cap Fund Direct-Growth</div></div><div class="band-content-right flt"><div class="head lbl">5Y Return</div><div class="values flt"><span class="per cSprite_b green">12.97 %
#                  </span></div><div class="cta flt">Invest Now</div></div></div></a></div></div></div>,
#  <div class="band-items" id="S1_box"><div class="band-item clearfix"><div class="band-content"><div class="head"><a href="https://economictimes.indiatimes.com/indices/nifty_50_companies" target="_blank">Benchmarks </a></div><div class="values"><a class="wname" href="https://economictimes.indiatimes.com/indices/nifty_50_companies" target="_blank">Nifty</a><span class="num">16,151.15</span><span class="per cSprite_b red">-64.85</span></div></div></div></div>,
#  <div class="band-item clearfix"><div class="band-content"><div class="head"><a href="https://economictimes.indiatimes.com/indices/nifty_50_companies" target="_blank">Benchmarks </a></div><div class="values"><a class="wname" href="https://economictimes.indiatimes.com/indices/nifty_50_companies" target="_blank">Nifty</a><span class="num">16,151.15</span><span class="per cSprite_b red">-64.85</span></div></div></div>,
#  <div class="band-content"><div class="head"><a href="https://economictimes.indiatimes.com/indices/nifty_50_companies" target="_blank">Benchmarks </a></div><div class="values"><a class="wname" href="https://economictimes.indiatimes.com/indices/nifty_50_companies" target="_blank">Nifty</a><span class="num">16,151.15</span><span class="per cSprite_b red">-64.85</span></div></div>,
#  <div class="head"><a href="https://economictimes.indiatimes.com/indices/nifty_50_companies" target="_blank">Benchmarks </a></div>,
#  <div class="values"><a class="wname" href="https://economictimes.indiatimes.com/indices/nifty_50_companies" target="_blank">Nifty</a><span class="num">16,151.15</span><span class="per cSprite_b red">-64.85</span></div>,
#  <div class="band-items" id="S2_box"><div class="band-item clearfix"><div class="band-content"><div class="head"><a href="https://economictimes.indiatimes.com/marketstats/duration-1d,marketcap-largecap,pageno-1,pid-0,sort-intraday,sortby-percentchange,sortorder-desc.cms" target="_blank">NSE Gainer-Large Cap </a></div><div class="values"><a class="wname" href="/adani-green-energy-ltd/stocks/companyid-64847.cms" target="_blank">Adani Green</a><span class="num">2,325.95</span><span class="per cSprite_b green">118.6</span></div></div></div></div>,
#  <div class="band-item clearfix"><div class="band-content"><div class="head"><a href="https://economictimes.indiatimes.com/marketstats/duration-1d,marketcap-largecap,pageno-1,pid-0,sort-intraday,sortby-percentchange,sortorder-desc.cms" target="_blank">NSE Gainer-Large Cap </a></div><div class="values"><a class="wname" href="/adani-green-energy-ltd/stocks/companyid-64847.cms" target="_blank">Adani Green</a><span class="num">2,325.95</span><span class="per cSprite_b green">118.6</span></div></div></div>,
#  <div class="band-content"><div class="head"><a href="https://economictimes.indiatimes.com/marketstats/duration-1d,marketcap-largecap,pageno-1,pid-0,sort-intraday,sortby-percentchange,sortorder-desc.cms" target="_blank">NSE Gainer-Large Cap </a></div><div class="values"><a class="wname" href="/adani-green-energy-ltd/stocks/companyid-64847.cms" target="_blank">Adani Green</a><span class="num">2,325.95</span><span class="per cSprite_b green">118.6</span></div></div>,
#  <div class="head"><a href="https://economictimes.indiatimes.com/marketstats/duration-1d,marketcap-largecap,pageno-1,pid-0,sort-intraday,sortby-percentchange,sortorder-desc.cms" target="_blank">NSE Gainer-Large Cap </a></div>,
#  <div class="values"><a class="wname" href="/adani-green-energy-ltd/stocks/companyid-64847.cms" target="_blank">Adani Green</a><span class="num">2,325.95</span><span class="per cSprite_b green">118.6</span></div>,
#  <div class="S5_box_wrapper"><div class="band-items" id="S5_box"><a data-ga-onclick="Buy Direct - Edelweiss#WEB - Click - Edelweiss Small Cap Fund Direct - Growth - Invest Now - MarketBand#MarketBand - url" href="https://www.edelweissmf.com/types-of-mutual-funds/equity-fund/edelweiss-small-cap-fund?utm_source=EconomicTimes&amp;utm_medium=Widget&amp;utm_campaign=ProductWidget&amp;utm_id=ETProductWidget&amp;utm_term=Edelweiss+Small+Cap%2C+Small+Cap%2C+Equity+Fund" rel="nofollow sponsored" target="_blank"><div class="band-item clearfix"><div class="band-content-left"><div class="head"><span class="lbl">FEATURED FUNDS</span><div class="ratings flr"><span class="rating">★★★★</span><span class="ratingGrey">★</span></div></div><div class="title" title="Edelweiss Small Cap Fund Direct - Growth">Edelweiss Small Cap Fund Direct - Growth</div></div><div class="band-content-right flt"><div class="head lbl">3Y Return</div><div class="values flt"><span class="per cSprite_b green">30.46 %
#                  </span></div><div class="cta flt">Invest Now</div></div></div></a><a data-ga-onclick="Buy Direct - DSP#WEB - Click - DSP Midcap Direct Plan-Growth - Invest Now - MarketBand#MarketBand - url" href="https://invest.dspim.com/mutual-fund-products/equity-schemes/mid-cap-small-and-mid-cap-fund/dspsm-direct-growth?utm_source=ET&amp;utm_medium=MF_Widget&amp;utm_campaign=ET-Midcap-Widget-Jul21&amp;utm_content=ET-Midcap-Widget" rel="nofollow sponsored" target="_blank"><div class="band-item clearfix"><div class="band-content-left"><div class="head"><span class="lbl">FEATURED FUNDS</span><div class="ratings flr"><span class="rating">★★★</span><span class="ratingGrey">★★</span></div></div><div class="title" title="DSP Midcap Direct Plan-Growth">DSP Midcap Direct Plan-Growth</div></div><div class="band-content-right flt"><div class="head lbl">5Y Return</div><div class="values flt"><span class="per cSprite_b green">10.65 %
#                  </span></div><div class="cta flt">Invest Now</div></div></div></a><a data-ga-onclick="Buy Direct - DSP#WEB - Click - DSP Tax Saver Direct Plan-Growth - Invest Now - MarketBand#MarketBand - url" href="https://invest.dspim.com/mutual-fund-products/equity-schemes/ELSS-tax-saver-fund/dspts-direct-growth?utm_source=ET&amp;utm_medium=MF_Widget&amp;utm_campaign=ET-ELSS-Widget-Jul21&amp;utm_content=ET-ELSS-Widget" rel="nofollow sponsored" target="_blank"><div class="band-item clearfix"><div class="band-content-left"><div class="head"><span class="lbl">FEATURED FUNDS</span><div class="ratings flr"><span class="rating">★★★★</span><span class="ratingGrey">★</span></div></div><div class="title" title="DSP Tax Saver Direct Plan-Growth">DSP Tax Saver Direct Plan-Growth</div></div><div class="band-content-right flt"><div class="head lbl">5Y Return</div><div class="values flt"><span class="per cSprite_b green">13.15 %
#                  </span></div><div class="cta flt">Invest Now</div></div></div></a><a data-ga-onclick="Buy Direct - Edelweiss#WEB - Click - Edelweiss Flexi Cap Fund Direct-Growth - Invest Now - MarketBand#MarketBand - url" href="https://www.edelweissmf.com/types-of-mutual-funds/equity-fund/edelweiss-flexicap-fund?utm_source=EconomicTimes&amp;utm_medium=Widget&amp;utm_campaign=ProductWidget&amp;utm_id=ETProductWidget&amp;utm_term=Edelweiss+Flexi+Cap%2C+Multi+Cap+Fund" rel="nofollow sponsored" target="_blank"><div class="band-item clearfix"><div class="band-content-left"><div class="head"><span class="lbl">FEATURED FUNDS</span><div class="ratings flr"><span class="rating">★★★</span><span class="ratingGrey">★★</span></div></div><div class="title" title="Edelweiss Flexi Cap Fund Direct-Growth">Edelweiss Flexi Cap Fund Direct-Growth</div></div><div class="band-content-right flt"><div class="head lbl">5Y Return</div><div class="values flt"><span class="per cSprite_b green">12.97 %
#                  </span></div><div class="cta flt">Invest Now</div></div></div></a></div></div>,
#  <div class="band-items" id="S5_box"><a data-ga-onclick="Buy Direct - Edelweiss#WEB - Click - Edelweiss Small Cap Fund Direct - Growth - Invest Now - MarketBand#MarketBand - url" href="https://www.edelweissmf.com/types-of-mutual-funds/equity-fund/edelweiss-small-cap-fund?utm_source=EconomicTimes&amp;utm_medium=Widget&amp;utm_campaign=ProductWidget&amp;utm_id=ETProductWidget&amp;utm_term=Edelweiss+Small+Cap%2C+Small+Cap%2C+Equity+Fund" rel="nofollow sponsored" target="_blank"><div class="band-item clearfix"><div class="band-content-left"><div class="head"><span class="lbl">FEATURED FUNDS</span><div class="ratings flr"><span class="rating">★★★★</span><span class="ratingGrey">★</span></div></div><div class="title" title="Edelweiss Small Cap Fund Direct - Growth">Edelweiss Small Cap Fund Direct - Growth</div></div><div class="band-content-right flt"><div class="head lbl">3Y Return</div><div class="values flt"><span class="per cSprite_b green">30.46 %
#                  </span></div><div class="cta flt">Invest Now</div></div></div></a><a data-ga-onclick="Buy Direct - DSP#WEB - Click - DSP Midcap Direct Plan-Growth - Invest Now - MarketBand#MarketBand - url" href="https://invest.dspim.com/mutual-fund-products/equity-schemes/mid-cap-small-and-mid-cap-fund/dspsm-direct-growth?utm_source=ET&amp;utm_medium=MF_Widget&amp;utm_campaign=ET-Midcap-Widget-Jul21&amp;utm_content=ET-Midcap-Widget" rel="nofollow sponsored" target="_blank"><div class="band-item clearfix"><div class="band-content-left"><div class="head"><span class="lbl">FEATURED FUNDS</span><div class="ratings flr"><span class="rating">★★★</span><span class="ratingGrey">★★</span></div></div><div class="title" title="DSP Midcap Direct Plan-Growth">DSP Midcap Direct Plan-Growth</div></div><div class="band-content-right flt"><div class="head lbl">5Y Return</div><div class="values flt"><span class="per cSprite_b green">10.65 %
#                  </span></div><div class="cta flt">Invest Now</div></div></div></a><a data-ga-onclick="Buy Direct - DSP#WEB - Click - DSP Tax Saver Direct Plan-Growth - Invest Now - MarketBand#MarketBand - url" href="https://invest.dspim.com/mutual-fund-products/equity-schemes/ELSS-tax-saver-fund/dspts-direct-growth?utm_source=ET&amp;utm_medium=MF_Widget&amp;utm_campaign=ET-ELSS-Widget-Jul21&amp;utm_content=ET-ELSS-Widget" rel="nofollow sponsored" target="_blank"><div class="band-item clearfix"><div class="band-content-left"><div class="head"><span class="lbl">FEATURED FUNDS</span><div class="ratings flr"><span class="rating">★★★★</span><span class="ratingGrey">★</span></div></div><div class="title" title="DSP Tax Saver Direct Plan-Growth">DSP Tax Saver Direct Plan-Growth</div></div><div class="band-content-right flt"><div class="head lbl">5Y Return</div><div class="values flt"><span class="per cSprite_b green">13.15 %
#                  </span></div><div class="cta flt">Invest Now</div></div></div></a><a data-ga-onclick="Buy Direct - Edelweiss#WEB - Click - Edelweiss Flexi Cap Fund Direct-Growth - Invest Now - MarketBand#MarketBand - url" href="https://www.edelweissmf.com/types-of-mutual-funds/equity-fund/edelweiss-flexicap-fund?utm_source=EconomicTimes&amp;utm_medium=Widget&amp;utm_campaign=ProductWidget&amp;utm_id=ETProductWidget&amp;utm_term=Edelweiss+Flexi+Cap%2C+Multi+Cap+Fund" rel="nofollow sponsored" target="_blank"><div class="band-item clearfix"><div class="band-content-left"><div class="head"><span class="lbl">FEATURED FUNDS</span><div class="ratings flr"><span class="rating">★★★</span><span class="ratingGrey">★★</span></div></div><div class="title" title="Edelweiss Flexi Cap Fund Direct-Growth">Edelweiss Flexi Cap Fund Direct-Growth</div></div><div class="band-content-right flt"><div class="head lbl">5Y Return</div><div class="values flt"><span class="per cSprite_b green">12.97 %
#                  </span></div><div class="cta flt">Invest Now</div></div></div></a></div>,
#  <div class="band-item clearfix"><div class="band-content-left"><div class="head"><span class="lbl">FEATURED FUNDS</span><div class="ratings flr"><span class="rating">★★★★</span><span class="ratingGrey">★</span></div></div><div class="title" title="Edelweiss Small Cap Fund Direct - Growth">Edelweiss Small Cap Fund Direct - Growth</div></div><div class="band-content-right flt"><div class="head lbl">3Y Return</div><div class="values flt"><span class="per cSprite_b green">30.46 %
#                  </span></div><div class="cta flt">Invest Now</div></div></div>,
#  <div class="band-content-left"><div class="head"><span class="lbl">FEATURED FUNDS</span><div class="ratings flr"><span class="rating">★★★★</span><span class="ratingGrey">★</span></div></div><div class="title" title="Edelweiss Small Cap Fund Direct - Growth">Edelweiss Small Cap Fund Direct - Growth</div></div>,
#  <div class="head"><span class="lbl">FEATURED FUNDS</span><div class="ratings flr"><span class="rating">★★★★</span><span class="ratingGrey">★</span></div></div>,
#  <div class="ratings flr"><span class="rating">★★★★</span><span class="ratingGrey">★</span></div>,
#  <div class="title" title="Edelweiss Small Cap Fund Direct - Growth">Edelweiss Small Cap Fund Direct - Growth</div>,
#  <div class="band-content-right flt"><div class="head lbl">3Y Return</div><div class="values flt"><span class="per cSprite_b green">30.46 %
#                  </span></div><div class="cta flt">Invest Now</div></div>,
#  <div class="head lbl">3Y Return</div>,
#  <div class="values flt"><span class="per cSprite_b green">30.46 %
#                  </span></div>,
#  <div class="cta flt">Invest Now</div>,
#  <div class="band-item clearfix"><div class="band-content-left"><div class="head"><span class="lbl">FEATURED FUNDS</span><div class="ratings flr"><span class="rating">★★★</span><span class="ratingGrey">★★</span></div></div><div class="title" title="DSP Midcap Direct Plan-Growth">DSP Midcap Direct Plan-Growth</div></div><div class="band-content-right flt"><div class="head lbl">5Y Return</div><div class="values flt"><span class="per cSprite_b green">10.65 %
#                  </span></div><div class="cta flt">Invest Now</div></div></div>,
#  <div class="band-content-left"><div class="head"><span class="lbl">FEATURED FUNDS</span><div class="ratings flr"><span class="rating">★★★</span><span class="ratingGrey">★★</span></div></div><div class="title" title="DSP Midcap Direct Plan-Growth">DSP Midcap Direct Plan-Growth</div></div>,
#  <div class="head"><span class="lbl">FEATURED FUNDS</span><div class="ratings flr"><span class="rating">★★★</span><span class="ratingGrey">★★</span></div></div>,
#  <div class="ratings flr"><span class="rating">★★★</span><span class="ratingGrey">★★</span></div>,
#  <div class="title" title="DSP Midcap Direct Plan-Growth">DSP Midcap Direct Plan-Growth</div>,
#  <div class="band-content-right flt"><div class="head lbl">5Y Return</div><div class="values flt"><span class="per cSprite_b green">10.65 %
#                  </span></div><div class="cta flt">Invest Now</div></div>,
#  <div class="head lbl">5Y Return</div>,
#  <div class="values flt"><span class="per cSprite_b green">10.65 %
#                  </span></div>,
#  <div class="cta flt">Invest Now</div>,
#  <div class="band-item clearfix"><div class="band-content-left"><div class="head"><span class="lbl">FEATURED FUNDS</span><div class="ratings flr"><span class="rating">★★★★</span><span class="ratingGrey">★</span></div></div><div class="title" title="DSP Tax Saver Direct Plan-Growth">DSP Tax Saver Direct Plan-Growth</div></div><div class="band-content-right flt"><div class="head lbl">5Y Return</div><div class="values flt"><span class="per cSprite_b green">13.15 %
#                  </span></div><div class="cta flt">Invest Now</div></div></div>,
#  <div class="band-content-left"><div class="head"><span class="lbl">FEATURED FUNDS</span><div class="ratings flr"><span class="rating">★★★★</span><span class="ratingGrey">★</span></div></div><div class="title" title="DSP Tax Saver Direct Plan-Growth">DSP Tax Saver Direct Plan-Growth</div></div>,
#  <div class="head"><span class="lbl">FEATURED FUNDS</span><div class="ratings flr"><span class="rating">★★★★</span><span class="ratingGrey">★</span></div></div>,
#  <div class="ratings flr"><span class="rating">★★★★</span><span class="ratingGrey">★</span></div>,
#  <div class="title" title="DSP Tax Saver Direct Plan-Growth">DSP Tax Saver Direct Plan-Growth</div>,
#  <div class="band-content-right flt"><div class="head lbl">5Y Return</div><div class="values flt"><span class="per cSprite_b green">13.15 %
#                  </span></div><div class="cta flt">Invest Now</div></div>,
#  <div class="head lbl">5Y Return</div>,
#  <div class="values flt"><span class="per cSprite_b green">13.15 %
#                  </span></div>,
#  <div class="cta flt">Invest Now</div>,
#  <div class="band-item clearfix"><div class="band-content-left"><div class="head"><span class="lbl">FEATURED FUNDS</span><div class="ratings flr"><span class="rating">★★★</span><span class="ratingGrey">★★</span></div></div><div class="title" title="Edelweiss Flexi Cap Fund Direct-Growth">Edelweiss Flexi Cap Fund Direct-Growth</div></div><div class="band-content-right flt"><div class="head lbl">5Y Return</div><div class="values flt"><span class="per cSprite_b green">12.97 %
#                  </span></div><div class="cta flt">Invest Now</div></div></div>,
#  <div class="band-content-left"><div class="head"><span class="lbl">FEATURED FUNDS</span><div class="ratings flr"><span class="rating">★★★</span><span class="ratingGrey">★★</span></div></div><div class="title" title="Edelweiss Flexi Cap Fund Direct-Growth">Edelweiss Flexi Cap Fund Direct-Growth</div></div>,
#  <div class="head"><span class="lbl">FEATURED FUNDS</span><div class="ratings flr"><span class="rating">★★★</span><span class="ratingGrey">★★</span></div></div>,
#  <div class="ratings flr"><span class="rating">★★★</span><span class="ratingGrey">★★</span></div>,
#  <div class="title" title="Edelweiss Flexi Cap Fund Direct-Growth">Edelweiss Flexi Cap Fund Direct-Growth</div>,
#  <div class="band-content-right flt"><div class="head lbl">5Y Return</div><div class="values flt"><span class="per cSprite_b green">12.97 %
#                  </span></div><div class="cta flt">Invest Now</div></div>,
#  <div class="head lbl">5Y Return</div>,
#  <div class="values flt"><span class="per cSprite_b green">12.97 %
#                  </span></div>,
#  <div class="cta flt">Invest Now</div>,
#  <div class="band-items grey"><div class="stats_btn"><a class="mktWatch" href="/marketstats/pid-0,pageno-1,sortby-percentchange,sortorder-desc,sort-intraday.cms?marketcap=largecap%252Cmidcap" target="_blank">Market Watch</a><div class="stats_list"></div></div></div>,
#  <div class="stats_btn"><a class="mktWatch" href="/marketstats/pid-0,pageno-1,sortby-percentchange,sortorder-desc,sort-intraday.cms?marketcap=largecap%252Cmidcap" target="_blank">Market Watch</a><div class="stats_list"></div></div>,
#  <div class="stats_list"></div>,
#  <div class="dtc vam logoPart tac"><a href="/" title="The Economic Times"><img alt="The Economic Times" class="dib" height="39" src="data:image/png;base64,..." width="407"/></a><a class="sec_logo bigLogo" href="/markets" id="mktLogo" title="ET Markets"><img alt="ET Markets" height="37" src="https://img.etimg.com/photo/msid-76931947,quality-100/et-markets-logo.jpg" width="163"/></a><div class="timeEdition tac"><div class="dib prel edition"><span>English Edition</span><span class="edMenu"><span class="ed">English Edition</span><a class="edHin" data-ga-onclick="Web Top Nav Edition#Hindi#url" href="https://economictimes.indiatimes.com/hindi" target="_blank">हिन्दी</a><a class="edHin" data-ga-onclick="Web Top Nav Edition#gujarati#url" href="https://gujarati.economictimes.com" rel="noopener nofollow" target="_blank">ગુજરાતી</a><a class="edHin" data-ga-onclick="Web Top Nav Edition#marathi#url" href="https://marathi.economictimes.com" rel="noopener nofollow" target="_blank">मराठी</a><a class="edHin" data-ga-onclick="Web Top Nav Edition#bengali#url" href="https://bengali.economictimes.com" rel="noopener nofollow" target="_blank">বাংলা</a><a class="edHin" data-ga-onclick="Web Top Nav Edition#kannada#url" href="https://kannada.economictimes.com" rel="noopener nofollow" target="_blank">ಕನ್ನಡ</a><a class="edHin" data-ga-onclick="Web Top Nav Edition#malayalam#url" href="https://malayalam.economictimes.com" rel="noopener nofollow" target="_blank">മലയാളം</a><a class="edHin" data-ga-onclick="Web Top Nav Edition#tamil#url" href="https://tamil.economictimes.com" rel="noopener nofollow" target="_blank">தமிழ்</a><a class="edHin" data-ga-onclick="Web Top Nav Edition#telugu#url" href="https://telugu.economictimes.com" rel="noopener nofollow" target="_blank">తెలుగు</a></span></div><span data-dt="2022-07-12 10:30:46.476"><span> | </span><span class="dib time">12 July, 2022, 10:30 AM IST</span></span><span> | </span><a class="dib epaper" data-ga-onclick="Web Top Nav Epaper link#Click on Epaper link#url" href="/printhome.cms" rel="nofollow" target="_blank">Print Edition</a></div><div class="flr subS
gpdownload"></span></a><a data-ga-onclick="App Store - href" href="http://itunes.apple.com/us/app/the-economic-times/id474766725?ls=1&amp;t=8apple.com/us" rel="nofollow" target="_blank"><span class="cSprite appstoredownload"></span></a></div><div class="flr box"><a data-ga-onclick="Subscription Flow#SYFT#Footer - url" href="/prime?utm_source=economictimes.indiatimes.com&amp;utm_medium=footer&amp;utm_campaign=ETPrimedistribution" target="_blank"><span class="cSprite primeIcon"></span></a></div><div class="flr box gdprEle" data-ga-action="Subscribe Newsletter"><a data-ga-onclick="Subscribe - href" href="https://economictimes.indiatimes.com/subscription" target="_blank"><span class="cSprite nwesltsub"></span><h4>subscribe to our newsletter</h4></a></div></div>,
#  <div class="flt box followUs" data-ga-action="Follow Us"><h3>Follow us on:</h3><a data-ga-onclick="Facebook - href" href="https://www.facebook.com/EconomicTimes" rel="nofollow" target="_blank" title="Facebook"><span class="cSprite fb"></span></a><a data-ga-onclick="Twitter - href" href="https://twitter.com/economictimes" rel="nofollow" target="_blank" title="Twitter"><span class="cSprite twt"></span></a><a data-ga-onclick="Linkedin - href" href="https://www.linkedin.com/company/economictimes" rel="nofollow" target="_blank" title="LinkedIn"><span class="cSprite linkin"></span></a><a data-ga-onclick="Rss - href" href="/rss.cms" target="_blank" title="RSS"><span class="cSprite rss"></span></a></div>,
#  <div class="flt box etDwnld" data-ga-action="Download ET App"><h2 class="uc" style="text-transform: none;">Download ET App:</h2><a data-ga-onclick="Play Store - href" href="https://market.android.com/details?id=com.et.reader.activities" rel="nofollow" target="_blank"><span class="cSprite gpdownload"></span></a><a data-ga-onclick="App Store - href" href="http://itunes.apple.com/us/app/the-economic-times/id474766725?ls=1&amp;t=8apple.com/us" rel="nofollow" target="_blank"><span class="cSprite appstoredownload"></span></a></div>,
#  <div class="flr box"><a data-ga-onclick="Subscription Flow#SYFT#Footer - url" href="/prime?utm_source=economictimes.indiatimes.com&amp;utm_medium=footer&amp;utm_campaign=ETPrimedistribution" target="_blank"><span class="cSprite primeIcon"></span></a></div>,
#  <div class="flr box gdprEle" data-ga-action="Subscribe Newsletter"><a data-ga-onclick="Subscribe - href" href="https://economictimes.indiatimes.com/subscription" target="_blank"><span class="cSprite nwesltsub"></span><h4>subscribe to our newsletter</h4></a></div>,
#  <div class="copyright" data-ga-action="Copyright">Copyright © 2022 Bennett, Coleman &amp; Co. Ltd. All rights reserved. For reprint rights: <a data-ga-onclick="Times Syndication Service - href" href="http://timescontent.com/" rel="nofollow" target="_blank">Times Syndication Service</a></div>,
#  <div id="scrollTop"><span></span>BACK TO TOP</div>,
#  <div data-adsslot="ET_ROS_NW/ET_ROS_Andbeyond_1x1" data-loc="All" data-size="[1, 1]" id="div-gpt-ad-1559650249467-0"></div>,
#  <div class="skipStickyBand stk_ftr_ad_exin" data-adsslot="ET_ROS_NW/ET_ROS_EX_IND_Sticky_728" data-loc="100" data-size="[728, 90]" id="div-gpt-ad-1649413409418-01" style="max-width: 728px; min-height: 90px; position: fixed; bottom: 0px;left:0;right:0;margin:0 auto;text-align: center;z-index: 999;"></div>]

# %%
soup.find_all('div',{'class':'eachStory'})
# Out:
# [<div class="eachStory" itemprop="itemListElement" itemscope="itemscope" itemtype="http://schema.org/ListItem"><meta content
chart Check: Did you know this FMCG stock has been moving in a rising channel for last 9 years? Time to buy" class="lazy" data-original="https://img.etimg.com/thumb/msid-92818465,width-160,height-120,imgsize-49814/chart-check-did-you-know-this-fmcg-stock-has-been-moving-in-a-rising-channel-for-last-9-years-time-to-buy.jpg" height="120" src="https://img.etimg.com/thumb/msid-42031747,width-160,height-120/etlogo.jpg" width="160"/></span></span><h3><a data-ga-onclick="1 - href" data-orefid="p2146843_1" href="/markets/stocks/news/chart-check-did-you-know-this-fmcg-stock-has-been-moving-in-a-rising-channel-for-last-9-years-time-to-buy/articleshow/92818465.cms" itemprop="url"><meta content="Chart Check: Did you know this FMCG stock has been moving in a rising channel for last 9 years? Time to buy" itemprop="name"/>Chart Check: Did you know this FMCG stock has been moving in a rising channel for last 9 years? Time to buy</a></h3><time class="date-format" data-time="Jul 12, 2022, 10:28 AM IST">Jul 12, 2022, 10:28 AM IST</time><p>“The stock has been moving up the channel for the last nine years. The recent decline brought stock on the rising arm's lower band where it had found its feet,” Kapil Shah, Technical Analyst, Emkay Global Financial Services Limited and Trainer at FinLearn Academy, said.</p></div>

# %%
soup.find_all('div',{'class':'eachStory'})[0].find('a')
# Out:
# <a data-ga-onclick="1 - href" data-orefid="p2146843_1" href="/markets/stocks/news/chart-check-did-you-know-this-fmcg-stock-has-been-moving-in-a-rising-channel-for-last-9-years-time-to-buy/articleshow/92818465.cms" itemprop="url"><meta content="Chart Check: Did you know this FMCG stock has been moving in a rising channel for last 9 years? Time to buy" itemprop="name"/>Chart Check: Did you know this FMCG stock has been moving in a rising channel for last 9 years? Time to buy</a>

# %%
soup.find_all('div',{'class':'eachStory'})[0].find_all('a')[-1].text
# Out:
# 'Chart Check: Did you know this FMCG stock has been moving in a rising channel for last 9 years? Time to buy'

# %%
#getting the whole paragraph of the title

# %%
i = 0
while i<10:
    print(i+1)
    print(soup.find_all('div',{'class':'eachStory'})[i].find_all('a')[-1].text)
    i+=1
# Out:
# 1
# Japan's Nikkei rises 1% as investors pick up cheap tech stocks
# 2
# European shares track Asian peers higher on China tariff relief hopes
# 3
# 2 sin stocks among top brokerage picks to shield your portfolio amid rising volatility
# 4
# How shifting to a new tax regime can impact Rs 1.5 lakh crore of ELSS fund flow
# 5
# How to buy stocks in a bear market? Nilesh Shah on the art behind investing
# 6
# HBD Rakesh Jhunjhunwala! How Big Bull made it big on Dalal Street
# 7
# Tortoise wins the race! ITC breaks record to turn Nifty topper
# 8
# What global brokerages say on Dalmia Bharat, HDFC merger & financials
# 9
# Chart Check: Why this Adani group stock could touch fresh 52-week highs in next 6 months
# 10
# Marksans Pharma rallies 12% after board sets date to consider buyback

# %%
i = 0
while i<10:
    print(i+1)
    print(soup.find_all('div',{'class':'eachStory'})[i].find_all('a')[-1].text)
    print(soup.find_all('div',{'class':'eachStory'})[i].find_all('p')[0].text)
    i+=1
# Out:
# 1
# Japan's Nikkei rises 1% as investors pick up cheap tech stocks
# "Investors took a fresh view on technology and growth stocks as U.S. yields stabled. They were buying back shares that fell too much." said Shoichi Arisawa, general manager of the investment research department at IwaiCosmo Securities.
# 2
# European shares track Asian peers higher on China tariff relief hopes
# Offering a brief respite to nervous markets was a report that U.S. President Joe Biden was contemplating rolling back some tariffs on Chinese imports, as well as news that Chinese Vice Premier Liu He had a "constructive" virtual dialogue with U.S. Treasury Secretary Janet Yellen.
# 3
# 2 sin stocks among top brokerage picks to shield your portfolio amid rising volatility
# Domestic brokerage firms have turned bullish on select consumption-related sectors ahead of monsoon. They are expecting recovery in these counters as the markets turn volatile. Interestingly, the majority of these names are from autos, FMCG and breweries. Here are the key picks recommended by brokerages to help shield your portfolio:
# 4
# How shifting to a new tax regime can impact Rs 1.5 lakh crore of ELSS fund flow
# The new tax regime has two main differentiating aspects. First, it offers more tax slabs. Second, it takes away all the exemptions and deductions available under Section 80, which is popular among taxpayers. So, if the cash in hand after adopting the new tax regime turns out to be higher than the benefit of tax deductions and exemptions available in the old tax regime, the taxpayer might choose the new tax regime.
# 5
# How to buy stocks in a bear market? Nilesh Shah on the art behind investing
# Urging investors to think of this bear market as an opportunity to make more money, the fund manager said the most exciting thing in a bear market is to be able to pick stocks at much below their fair value.
# 6
# HBD Rakesh Jhunjhunwala! How Big Bull made it big on Dalal Street
# “Trading and investing are like having a wife and a mistress. You can’t manage both well. So, keep them apart. One should not know anything about the other,” Jhunjhunwala said in a 2018 interview.
# 7
# Tortoise wins the race! ITC breaks record to turn Nifty topper
# ITC shares, which hit a 52-week high of Rs 293.30 on Monday, have so far rallied over 33 per cent in 2022. As a result, the cigarettes-to-hotels conglomerate is now the top performer in Nifty pack on a year-to-date basis.
# 8
# What global brokerages say on Dalmia Bharat, HDFC merger & financials
# JP Morgan has maintained its 'overweight' stance on cement company Dalmia Bharat with a target price of Rs 1,680 on the counter. However, it has further cut its consensus earnings for the company. The brokerage said the earnings outlook remains hazy, though Q2 should be the bottom and if coal prices stay high, pricing power will be limited.
# 9
# Chart Check: Why this Adani group stock could touch fresh 52-week highs in next 6 months
# The stock hit a 52-week high of Rs 2420 on 27 April 2022 but then the trend went sideways. Recent price action pushed the stock above the 50-DMA which is a positive sign. Short-term traders can look to buy the stock now or on dips for a possible target of Rs 2800 which would result in fresh 52-week highs in the next 6 months, suggest experts.
# 10
# Marksans Pharma rallies 12% after board sets date to consider buyback
# Marksans Pharma’s filing to the exchanges about the buyback proposal said a meeting of the Board of Directors of the Company is scheduled to be held on Friday, 8th July 2022 to consider the proposal for buyback of fully paid-up equity shares of the company.

# %%
i = 0
while i<10:
    print(str(i+1)+":")
    print(soup.find_all('div',{'class':'eachStory'})[i].find_all('a')[-1].text)
    print(soup.find_all('div',{'class':'eachStory'})[i].find_all('p')[0].text)
    i+=1
# Out:
# 1:
# Japan's Nikkei rises 1% as investors pick up cheap tech stocks
# "Investors took a fresh view on technology and growth stocks as U.S. yields stabled. They were buying back shares that fell too much." said Shoichi Arisawa, general manager of the investment research department at IwaiCosmo Securities.
# 2:
# European shares track Asian peers higher on China tariff relief hopes
# Offering a brief respite to nervous markets was a report that U.S. President Joe Biden was contemplating rolling back some tariffs on Chinese imports, as well as news that Chinese Vice Premier Liu He had a "constructive" virtual dialogue with U.S. Treasury Secretary Janet Yellen.
# 3:
# 2 sin stocks among top brokerage picks to shield your portfolio amid rising volatility
# Domestic brokerage firms have turned bullish on select consumption-related sectors ahead of monsoon. They are expecting recovery in these counters as the markets turn volatile. Interestingly, the majority of these names are from autos, FMCG and breweries. Here are the key picks recommended by brokerages to help shield your portfolio:
# 4:
# How shifting to a new tax regime can impact Rs 1.5 lakh crore of ELSS fund flow
# The new tax regime has two main differentiating aspects. First, it offers more tax slabs. Second, it takes away all the exemptions and deductions available under Section 80, which is popular among taxpayers. So, if the cash in hand after adopting the new tax regime turns out to be higher than the benefit of tax deductions and exemptions available in the old tax regime, the taxpayer might choose the new tax regime.
# 5:
# How to buy stocks in a bear market? Nilesh Shah on the art behind investing
# Urging investors to think of this bear market as an opportunity to make more money, the fund manager said the most exciting thing in a bear market is to be able to pick stocks at much below their fair value.
# 6:
# HBD Rakesh Jhunjhunwala! How Big Bull made it big on Dalal Street
# “Trading and investing are like having a wife and a mistress. You can’t manage both well. So, keep them apart. One should not know anything about the other,” Jhunjhunwala said in a 2018 interview.
# 7:
# Tortoise wins the race! ITC breaks record to turn Nifty topper
# ITC shares, which hit a 52-week high of Rs 293.30 on Monday, have so far rallied over 33 per cent in 2022. As a result, the cigarettes-to-hotels conglomerate is now the top performer in Nifty pack on a year-to-date basis.
# 8:
# What global brokerages say on Dalmia Bharat, HDFC merger & financials
# JP Morgan has maintained its 'overweight' stance on cement company Dalmia Bharat with a target price of Rs 1,680 on the counter. However, it has further cut its consensus earnings for the company. The brokerage said the earnings outlook remains hazy, though Q2 should be the bottom and if coal prices stay high, pricing power will be limited.
# 9:
# Chart Check: Why this Adani group stock could touch fresh 52-week highs in next 6 months
# The stock hit a 52-week high of Rs 2420 on 27 April 2022 but then the trend went sideways. Recent price action pushed the stock above the 50-DMA which is a positive sign. Short-term traders can look to buy the stock now or on dips for a possible target of Rs 2800 which would result in fresh 52-week highs in the next 6 months, suggest experts.
# 10:
# Marksans Pharma rallies 12% after board sets date to consider buyback
# Marksans Pharma’s filing to the exchanges about the buyback proposal said a meeting of the Board of Directors of the Company is scheduled to be held on Friday, 8th July 2022 to consider the proposal for buyback of fully paid-up equity shares of the company.

# %%
i = 0
while i<10:
    
    headline = (soup.find_all('div',{'class':'eachStory'})[i].find_all('a')[-1].text)
    print(str(i+1)+":"+ headline)
    print(soup.find_all('div',{'class':'eachStory'})[i].find_all('p')[0].text)
    i+=1
# Out:
# 1:Japan's Nikkei rises 1% as investors pick up cheap tech stocks
# "Investors took a fresh view on technology and growth stocks as U.S. yields stabled. They were buying back shares that fell too much." said Shoichi Arisawa, general manager of the investment research department at IwaiCosmo Securities.
# 2:European shares track Asian peers higher on China tariff relief hopes
# Offering a brief respite to nervous markets was a report that U.S. President Joe Biden was contemplating rolling back some tariffs on Chinese imports, as well as news that Chinese Vice Premier Liu He had a "constructive" virtual dialogue with U.S. Treasury Secretary Janet Yellen.
# 3:2 sin stocks among top brokerage picks to shield your portfolio amid rising volatility
# Domestic brokerage firms have turned bullish on select consumption-related sectors ahead of monsoon. They are expecting recovery in these counters as the markets turn volatile. Interestingly, the majority of these names are from autos, FMCG and breweries. Here are the key picks recommended by brokerages to help shield your portfolio:
# 4:How shifting to a new tax regime can impact Rs 1.5 lakh crore of ELSS fund flow
# The new tax regime has two main differentiating aspects. First, it offers more tax slabs. Second, it takes away all the exemptions and deductions available under Section 80, which is popular among taxpayers. So, if the cash in hand after adopting the new tax regime turns out to be higher than the benefit of tax deductions and exemptions available in the old tax regime, the taxpayer might choose the new tax regime.
# 5:How to buy stocks in a bear market? Nilesh Shah on the art behind investing
# Urging investors to think of this bear market as an opportunity to make more money, the fund manager said the most exciting thing in a bear market is to be able to pick stocks at much below their fair value.
# 6:HBD Rakesh Jhunjhunwala! How Big Bull made it big on Dalal Street
# “Trading and investing are like having a wife and a mistress. You can’t manage both well. So, keep them apart. One should not know anything about the other,” Jhunjhunwala said in a 2018 interview.
# 7:Tortoise wins the race! ITC breaks record to turn Nifty topper
# ITC shares, which hit a 52-week high of Rs 293.30 on Monday, have so far rallied over 33 per cent in 2022. As a result, the cigarettes-to-hotels conglomerate is now the top performer in Nifty pack on a year-to-date basis.
# 8:What global brokerages say on Dalmia Bharat, HDFC merger & financials
# JP Morgan has maintained its 'overweight' stance on cement company Dalmia Bharat with a target price of Rs 1,680 on the counter. However, it has further cut its consensus earnings for the company. The brokerage said the earnings outlook remains hazy, though Q2 should be the bottom and if coal prices stay high, pricing power will be limited.
# 9:Chart Check: Why this Adani group stock could touch fresh 52-week highs in next 6 months
# The stock hit a 52-week high of Rs 2420 on 27 April 2022 but then the trend went sideways. Recent price action pushed the stock above the 50-DMA which is a positive sign. Short-term traders can look to buy the stock now or on dips for a possible target of Rs 2800 which would result in fresh 52-week highs in the next 6 months, suggest experts.
# 10:Marksans Pharma rallies 12% after board sets date to consider buyback
# Marksans Pharma’s filing to the exchanges about the buyback proposal said a meeting of the Board of Directors of the Company is scheduled to be held on Friday, 8th July 2022 to consider the proposal for buyback of fully paid-up equity shares of the company.

# %%
i = 0
while i<10:
    
    headline = (soup.find_all('div',{'class':'eachStory'})[i].find_all('a')[-1].text)
    print(str(i+1)+":"+ headline)
    print(soup.find_all('div',{'class':'eachStory'})[i].find_all('p')[0].text)
    print()
    i+=1
# Out:
# 1:Japan's Nikkei rises 1% as investors pick up cheap tech stocks
# "Investors took a fresh view on technology and growth stocks as U.S. yields stabled. They were buying back shares that fell too much." said Shoichi Arisawa, general manager of the investment research department at IwaiCosmo Securities.
#
# 2:European shares track Asian peers higher on China tariff relief hopes
# Offering a brief respite to nervous markets was a report that U.S. President Joe Biden was contemplating rolling back some tariffs on Chinese imports, as well as news that Chinese Vice Premier Liu He had a "constructive" virtual dialogue with U.S. Treasury Secretary Janet Yellen.
#
# 3:2 sin stocks among top brokerage picks to shield your portfolio amid rising volatility
# Domestic brokerage firms have turned bullish on select consumption-related sectors ahead of monsoon. They are expecting recovery in these counters as the markets turn volatile. Interestingly, the majority of these names are from autos, FMCG and breweries. Here are the key picks recommended by brokerages to help shield your portfolio:
#
# 4:How shifting to a new tax regime can impact Rs 1.5 lakh crore of ELSS fund flow
# The new tax regime has two main differentiating aspects. First, it offers more tax slabs. Second, it takes away all the exemptions and deductions available under Section 80, which is popular among taxpayers. So, if the cash in hand after adopting the new tax regime turns out to be higher than the benefit of tax deductions and exemptions available in the old tax regime, the taxpayer might choose the new tax regime.
#
# 5:How to buy stocks in a bear market? Nilesh Shah on the art behind investing
# Urging investors to think of this bear market as an opportunity to make more money, the fund manager said the most exciting thing in a bear market is to be able to pick stocks at much below their fair value.
#
# 6:HBD Rakesh Jhunjhunwala! How Big Bull made it big on Dalal Street
# “Trading and investing are like having a wife and a mistress. You can’t manage both well. So, keep them apart. One should not know anything about the other,” Jhunjhunwala said in a 2018 interview.
#
# 7:Tortoise wins the race! ITC breaks record to turn Nifty topper
# ITC shares, which hit a 52-week high of Rs 293.30 on Monday, have so far rallied over 33 per cent in 2022. As a result, the cigarettes-to-hotels conglomerate is now the top performer in Nifty pack on a year-to-date basis.
#
# 8:What global brokerages say on Dalmia Bharat, HDFC merger & financials
# JP Morgan has maintained its 'overweight' stance on cement company Dalmia Bharat with a target price of Rs 1,680 on the counter. However, it has further cut its consensus earnings for the company. The brokerage said the earnings outlook remains hazy, though Q2 should be the bottom and if coal prices stay high, pricing power will be limited.
#
# 9:Chart Check: Why this Adani group stock could touch fresh 52-week highs in next 6 months
# The stock hit a 52-week high of Rs 2420 on 27 April 2022 but then the trend went sideways. Recent price action pushed the stock above the 50-DMA which is a positive sign. Short-term traders can look to buy the stock now or on dips for a possible target of Rs 2800 which would result in fresh 52-week highs in the next 6 months, suggest experts.
#
# 10:Marksans Pharma rallies 12% after board sets date to consider buyback
# Marksans Pharma’s filing to the exchanges about the buyback proposal said a meeting of the Board of Directors of the Company is scheduled to be held on Friday, 8th July 2022 to consider the proposal for buyback of fully paid-up equity shares of the company.

# %%
def getNews():
    r = requests.get(url, {'headers':headers})
    soup = BeautifulSoup(r.text, 'html.parser')
    soup.find_all('div',{'class':'eachStory'})[0].find_all('a')[-1].text
    i = 0
    while i<10:
        headline = (soup.find_all('div',{'class':'eachStory'})[i].find_all('a')[-1].text)
        print(str(i+1)+":"+ headline)
        print(soup.find_all('div',{'class':'eachStory'})[i].find_all('p')[0].text)
        print()
        i+=1

# %%
getNews()
# Out:
# 1:Reliance, ONGC’s credit quality can bear windfall tax, says Moody's
# “While profits generated from oil exports will fall because of windfall taxes, they will likely remain higher than the levels over April 2020 to March 2022 if refining margins are sustained at the highs seen in April to June this year,” wrote Moody’s analyst Hui Ting Sim in a note. “High crude oil prices will support the earnings of oil producers.
#
# 2:PTC India Financial Services shares zoom 20%; here's why
# According to a press release issued by the company, the ASM report said that it is maintaining the required level of transparency in terms of submission of data/statements to the lenders as stipulated at the time of sanction.
#
# 3:2 sin stocks among top brokerage picks to shield your portfolio amid rising volatility
# Domestic brokerage firms have turned bullish on select consumption-related sectors ahead of monsoon. They are expecting recovery in these counters as the markets turn volatile. Interestingly, the majority of these names are from autos, FMCG and breweries. Here are the key picks recommended by brokerages to help shield your portfolio:
#
# 4:MMTC shares rally 10% on transfer of stake in Neelachal Ispat Nigam
# The share purchase agreement was signed on March 10, following which the buyer, NINL and the six selling shareholders worked towards satisfying a set of conditions defined in the SPA, including certification of operational creditor's dues, employees' dues, sellers' operational and financial dues.
#
# 5:Japan's Nikkei rises 1% as investors pick up cheap tech stocks
# "Investors took a fresh view on technology and growth stocks as U.S. yields stabled. They were buying back shares that fell too much." said Shoichi Arisawa, general manager of the investment research department at IwaiCosmo Securities.
#
# 6:European shares track Asian peers higher on China tariff relief hopes
# Offering a brief respite to nervous markets was a report that U.S. President Joe Biden was contemplating rolling back some tariffs on Chinese imports, as well as news that Chinese Vice Premier Liu He had a "constructive" virtual dialogue with U.S. Treasury Secretary Janet Yellen.
#
# 7:How shifting to a new tax regime can impact Rs 1.5 lakh crore of ELSS fund flow
# The new tax regime has two main differentiating aspects. First, it offers more tax slabs. Second, it takes away all the exemptions and deductions available under Section 80, which is popular among taxpayers. So, if the cash in hand after adopting the new tax regime turns out to be higher than the benefit of tax deductions and exemptions available in the old tax regime, the taxpayer might choose the new tax regime.
#
# 8:How to buy stocks in a bear market? Nilesh Shah on the art of investing
# Urging investors to think of this bear market as an opportunity to make more money, the fund manager said the most exciting thing in a bear market is to be able to pick stocks at much below their fair value.
#
# 9:HBD Rakesh Jhunjhunwala! How Big Bull made it big on Dalal Street
# “Trading and investing are like having a wife and a mistress. You can’t manage both well. So, keep them apart. One should not know anything about the other,” Jhunjhunwala said in a 2018 interview.
#
# 10:Tortoise wins the race! ITC breaks record to turn Nifty topper
# ITC shares, which hit a 52-week high of Rs 293.30 on Monday, have so far rallied over 33 per cent in 2022. As a result, the cigarettes-to-hotels conglomerate is now the top performer in Nifty pack on a year-to-date basis.

# %%
def getNews():
    r = requests.get(url, {'headers':headers})
    soup = BeautifulSoup(r.text, 'html.parser')
    soup.find_all('div',{'class':'eachStory'})[0].find_all('a')[-1].text
    i = 0
    length = len(soup.find_all('div',{'class':'eachStory'}))
    while i<length:
        headline = (soup.find_all('div',{'class':'eachStory'})[i].find_all('a')[-1].text)
        print(str(i+1)+":"+ headline)
        print(soup.find_all('div',{'class':'eachStory'})[i].find_all('p')[0].text)
        print()
        i+=1

# %%
len(soup.find_all('div',{'class':'eachStory'}))
# Out:
# 16

# %%
getNews()
# Out:
# 1:Reliance, ONGC’s credit quality can bear windfall tax, says Moody's
# “While profits generated from oil exports will fall because of windfall taxes, they will likely remain higher than the levels over April 2020 to March 2022 if refining margins are sustained at the highs seen in April to June this year,” wrote Moody’s analyst Hui Ting Sim in a note. “High crude oil prices will support the earnings of oil producers.
#
# 2:PTC India Financial Services shares zoom 20%; here's why
# According to a press release issued by the company, the ASM report said that it is maintaining the required level of transparency in terms of submission of data/statements to the lenders as stipulated at the time of sanction.
#
# 3:2 sin stocks among top brokerage picks to shield your portfolio amid rising volatility
# Domestic brokerage firms have turned bullish on select consumption-related sectors ahead of monsoon. They are expecting recovery in these counters as the markets turn volatile. Interestingly, the majority of these names are from autos, FMCG and breweries. Here are the key picks recommended by brokerages to help shield your portfolio:
#
# 4:MMTC shares rally 10% on transfer of stake in Neelachal Ispat Nigam
# The share purchase agreement was signed on March 10, following which the buyer, NINL and the six selling shareholders worked towards satisfying a set of conditions defined in the SPA, including certification of operational creditor's dues, employees' dues, sellers' operational and financial dues.
#
# 5:Japan's Nikkei rises 1% as investors pick up cheap tech stocks
# "Investors took a fresh view on technology and growth stocks as U.S. yields stabled. They were buying back shares that fell too much." said Shoichi Arisawa, general manager of the investment research department at IwaiCosmo Securities.
